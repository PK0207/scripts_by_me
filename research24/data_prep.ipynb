# %%
import os
import numpy as np
import pandas as pd
from glob import glob
from astropy.io import fits
from astropy.table import Table
from empirical_functions import spectrum, ModelFitting

# %% [markdown]
# # Initialize spectrum class with HST files
# The data is interesting, I don't have older data, and the cspec files are weird.

# %%
all_spectra.spec_df.keys()
# Out:
# Index(['filename', 'obsdate', 'instrument', 'filter', 'dispfile', 'LSFfile',
#        'cenwave', 'wavelength', 'flux', 'fluxerr', 'segment', 'H2line_idx',
#        '[nu', J']', 'labline', 'transition_prob'],
#       dtype='object')

# %%
cspec_spectra.spec_df.keys()
# Out:
# Index(['filename', 'obsdate', 'instrument', 'filter', 'dispfile', 'LSFfile',
#        'cenwave', 'wavelength', 'flux', 'fluxerr', 'segment', 'H2line_idx',
#        '[nu', J']', 'labline', 'transition_prob'],
#       dtype='object')

# %%
line_df.keys()
# Out:
# Index(['filename', 'obsdate', 'instrument', 'filter', 'dispfile', 'LSFfile',
#        'cenwave', 'wavelength', 'flux', 'fluxerr', 'velocity', 'segment',
#        'H2line_idx', 'labline', 'transition_prob', 'transition'],
#       dtype='object')

# %%
cspec_files = glob(os.path.join('HST', 'anonymous37222', '*cspec.fits'))
cspec_spectra = spectrum(cspec_files, linelist_file='HST/emission_lines.csv', dataDir='HST/')
cspec_spectra.coaddwave(cspec_spectra.spec_df, columns = ['obsdate', 'filter'])
cspec_spectra.H2lines_fromspectrum(cspec_spectra.spec_df)
# Out:
#                                              filename     obsdate instrument  \
# 0   HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-12        COS
# 1   HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-13        COS
# 2   HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-16        COS
# 3   HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-15        COS
# 4   HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-21        COS
# 5   HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-14        COS
# 6   HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-21        COS
# 7   HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-18        COS
# 8   HST/anonymous37222/hst_12036_cos_v-ru-lupi_g13...  2012-02-28        COS
# 9   HST/anonymous37222/hst_12036_cos_v-ru-lupi_g16...  2011-07-20        COS
# 10  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-10        COS
# 11  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-15        COS
# 12  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-15        COS
# 13  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-10        COS
# 14  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-13        COS
# 15  HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-14        COS
# 16  HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-18        COS
# 17  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-14        COS
# 18  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-21        COS
# 19  HST/anonymous37222/hst_12036_cos_v-ru-lupi_g16...  2012-02-28        COS
# 20  HST/anonymous37222/hst_12036_cos_v-ru-lupi_g13...  2012-02-28        COS
# 21  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-11        COS
# 22  HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-11        COS
# 23  HST/anonymous37222/hst_16592_cos_v-ru-lup_cg23...  2022-08-10        COS
# 24  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-17        COS
# 25  HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-10        COS
# 26  HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-17        COS
# 27  HST/anonymous37222/hst_8157_stis_hd142560_e140...  2000-07-12       STIS
# 28  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-20        COS
# 29  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-16        COS
# 30  HST/anonymous37222/hst_8157_stis_hd142560_e140...  2000-07-12       STIS
# 31  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-12        COS
# 32  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-17        COS
# 33  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-12        COS
# 34  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-11        COS
# 35  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-20        COS
# 36  HST/anonymous37222/hst_16110_cos_v-ru-lup_g160...  2021-08-18        COS
# 37  HST/anonymous37222/hst_8157_stis_hd142560_g430...  2000-07-12       STIS
# 38  HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-20        COS
# 39  HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-16        COS
# 40  HST/anonymous37222/hst_16110_cos_v-ru-lup_cg23...  2021-08-13        COS
#
#          filter dispfile LSFfile cenwave  \
# 0         G230L     None    None   MULTI
# 1   G160M-G230L     None    None   MULTI
# 2         G160M     None    None   MULTI
# 3         G230L     None    None   MULTI
# 4         G230L     None    None   MULTI
# 5         G160M     None    None   MULTI
# 6         G160M     None    None   MULTI
# 7   G160M-G230L     None    None   MULTI
# 8         G130M     None    None   MULTI
# 9         G160M     None    None    1611
# 10  G160M-G230L     None    None   MULTI
# 11        G160M     None    None   MULTI
# 12  G160M-G230L     None    None   MULTI
# 13        G160M     None    None   MULTI
# 14        G160M     None    None   MULTI
# 15        G230L     None    None   MULTI
# 16        G230L     None    None   MULTI
# 17  G160M-G230L     None    None   MULTI
# 18  G160M-G230L     None    None   MULTI
# 19        G160M     None    None   MULTI
# 20  G130M-G160M     None    None   MULTI
# 21        G160M     None    None   MULTI
# 22        G230L     None    None   MULTI
# 23        G230L     None    None   MULTI
# 24  G160M-G230L     None    None   MULTI
# 25        G230L     None    None   MULTI
# 26        G230L     None    None   MULTI
# 27  E140M-G430L     None    None   MULTI
# 28  G160M-G230L     None    None   MULTI
# 29  G160M-G230L     None    None   MULTI
# 30        E140M     None    None    1425
# 31        G160M     None    None   MULTI
# 32        G160M     None    None   MULTI
# 33  G160M-G230L     None    None   MULTI
# 34  G160M-G230L     None    None   MULTI
# 35        G160M     None    None   MULTI
# 36        G160M     None    None   MULTI
# 37        G430L     None    None    4300
# 38        G230L     None    None   MULTI
# 39        G230L     None    None   MULTI
# 40        G230L     None    None   MULTI
#
#                                            wavelength  \
# 0   [1413.6094970703125 Angstrom, 1414.0244140625 ...
# 1   [1395.40234375 Angstrom, 1395.41455078125 Angs...
# 2   [1395.4390869140625 Angstrom, 1395.45129394531...
# 3   [1402.409423828125 Angstrom, 1402.824340820312...
# 4   [1418.1739501953125 Angstrom, 1418.5888671875 ...
# 5   [1395.3778076171875 Angstrom, 1395.39001464843...
# 6   [1395.41455078125 Angstrom, 1395.4267578125 An...
# 7   [1395.4512939453125 Angstrom, 1395.46362304687...
# 8   [1135.59619140625 Angstrom, 1135.606201171875 ...
# 9   [1422.6502685546875 Angstrom, 1422.66259765625...
# 10  [1395.537109375 Angstrom, 1395.54931640625 Ang...
# 11  [1395.54931640625 Angstrom, 1395.5616455078125...
# 12  [1395.5616455078125 Angstrom, 1395.57385253906...
# 13  [1395.328857421875 Angstrom, 1395.341064453125...
# 14  [1395.3900146484375 Angstrom, 1395.40234375 An...
# 15  [1399.9183349609375 Angstrom, 1400.33325195312...
# 16  [1416.5140380859375 Angstrom, 1416.92895507812...
# 17  [1395.3900146484375 Angstrom, 1395.40234375 An...
# 18  [1395.4267578125 Angstrom, 1395.4390869140625 ...
# 19  [1399.850341796875 Angstrom, 1399.862670898437...
# 20  [1135.606201171875 Angstrom, 1135.616088867187...
# 21  [1395.475830078125 Angstrom, 1395.488159179687...
# 22  [1401.166748046875 Angstrom, 1401.581787109375...
# 23  [1389.9617919921875 Angstrom, 1390.37670898437...
# 24  [1395.341064453125 Angstrom, 1395.353271484375...
# 25  [1397.016357421875 Angstrom, 1397.431274414062...
# 26  [1397.013671875 Angstrom, 1397.4285888671875 A...
# 27  [1141.602294921875 Angstrom, 1141.620727539062...
# 28  [1395.4512939453125 Angstrom, 1395.46362304687...
# 29  [1395.4512939453125 Angstrom, 1395.46362304687...
# 30  [1140.497314453125 Angstrom, 1140.515747070312...
# 31  [1395.5738525390625 Angstrom, 1395.58605957031...
# 32  [1395.328857421875 Angstrom, 1395.341064453125...
# 33  [1395.5860595703125 Angstrom, 1395.59838867187...
# 34  [1395.4881591796875 Angstrom, 1395.50036621093...
# 35  [1395.4390869140625 Angstrom, 1395.45129394531...
# 36  [1395.4390869140625 Angstrom, 1395.45129394531...
# 37  [2985.4638671875 Angstrom, 2988.208984375 Angs...
# 38  [1401.16552734375 Angstrom, 1401.5804443359375...
# 39  [1399.0870361328125 Angstrom, 1399.50183105468...
# 40  [1403.6513671875 Angstrom, 1404.0662841796875 ...
#
#                                                  flux  \
# 0   [-1.1882458572642918e-08 erg / (Angstrom s cm2...
# 1   [-2.343575556110751e-17 erg / (Angstrom s cm2)...
# 2   [7.786828094217407e-15 erg / (Angstrom s cm2),...
# 3   [-3.960328953667158e-09 erg / (Angstrom s cm2)...
# 4   [-9.095240116607783e-09 erg / (Angstrom s cm2)...
# 5   [7.819889484214637e-15 erg / (Angstrom s cm2),...
# 6   [1.572425864645663e-14 erg / (Angstrom s cm2),...
# 7   [7.833256511155257e-15 erg / (Angstrom s cm2),...
# 8   [3.3927773412164176e-15 erg / (Angstrom s cm2)...
# 9   [1.6265634672496532e-14 erg / (Angstrom s cm2)...
# 10  [3.09713099418585e-14 erg / (Angstrom s cm2), ...
# 11  [2.3672920855576443e-14 erg / (Angstrom s cm2)...
# 12  [3.1558255493427737e-14 erg / (Angstrom s cm2)...
# 13  [3.146919506122163e-14 erg / (Angstrom s cm2),...
# 14  [3.931575253074762e-14 erg / (Angstrom s cm2),...
# 15  [3.231153122840169e-09 erg / (Angstrom s cm2),...
# 16  [6.74281519508213e-09 erg / (Angstrom s cm2), ...
# 17  [3.14061487048916e-14 erg / (Angstrom s cm2), ...
# 18  [3.9369966027503686e-14 erg / (Angstrom s cm2)...
# 19  [5.0242758765266585e-14 erg / (Angstrom s cm2)...
# 20  [-2.772991184081609e-16 erg / (Angstrom s cm2)...
# 21  [-8.496361839036782e-17 erg / (Angstrom s cm2)...
# 22  [-1.6516823464485242e-09 erg / (Angstrom s cm2...
# 23  [1.6841754657548336e-09 erg / (Angstrom s cm2)...
# 24  [2.359806516589579e-14 erg / (Angstrom s cm2),...
# 25  [-6.079762027155766e-09 erg / (Angstrom s cm2)...
# 26  [-6.079762027155766e-09 erg / (Angstrom s cm2)...
# 27  [-5.424865309570925e-12 erg / (Angstrom s cm2)...
# 28  [7.846177151732674e-15 erg / (Angstrom s cm2),...
# 29  [7.784802838440522e-15 erg / (Angstrom s cm2),...
# 30  [-1.5094661978687363e-10 erg / (Angstrom s cm2...
# 31  [2.3618717523215746e-14 erg / (Angstrom s cm2)...
# 32  [3.146919506122163e-14 erg / (Angstrom s cm2),...
# 33  [7.844067192661064e-15 erg / (Angstrom s cm2),...
# 34  [-8.495896632660282e-17 erg / (Angstrom s cm2)...
# 35  [1.5714934507773254e-14 erg / (Angstrom s cm2)...
# 36  [1.571215285157447e-14 erg / (Angstrom s cm2),...
# 37  [4.0675271581903233e-13 erg / (Angstrom s cm2)...
# 38  [4.775200679318914e-09 erg / (Angstrom s cm2),...
# 39  [2.6484108239799298e-09 erg / (Angstrom s cm2)...
# 40  [2.119930231359035e-09 erg / (Angstrom s cm2),...
#
#                                               fluxerr segment  \
# 0   [3.5922305367940494e-09 erg / (Angstrom s cm2)...    None
# 1   [3.5069690744130666e-15 erg / (Angstrom s cm2)...    None
# 2   [5.506211218443105e-15 erg / (Angstrom s cm2),...    None
# 3   [5.138981038487556e-09 erg / (Angstrom s cm2),...    None
# 4   [3.591790918298872e-09 erg / (Angstrom s cm2),...    None
# 5   [5.5295496206176025e-15 erg / (Angstrom s cm2)...    None
# 6   [7.862200908491788e-15 erg / (Angstrom s cm2),...    None
# 7   [5.538997316936574e-15 erg / (Angstrom s cm2),...    None
# 8   [2.125946078252652e-15 erg / (Angstrom s cm2),...    None
# 9   [2.7960069763874706e-15 erg / (Angstrom s cm2)...    None
# 10  [9.825474803385942e-15 erg / (Angstrom s cm2),...    None
# 11  [9.664446044472983e-15 erg / (Angstrom s cm2),...    None
# 12  [1.1157554673252939e-14 erg / (Angstrom s cm2)...    None
# 13  [1.1126062084868046e-14 erg / (Angstrom s cm2)...    None
# 14  [1.2432773177110696e-14 erg / (Angstrom s cm2)...    None
# 15  [7.228728244267295e-09 erg / (Angstrom s cm2),...    None
# 16  [6.980750997967594e-09 erg / (Angstrom s cm2),...    None
# 17  [1.1103794660811226e-14 erg / (Angstrom s cm2)...    None
# 18  [1.244992804685814e-14 erg / (Angstrom s cm2),...    None
# 19  [4.9832787525244805e-15 erg / (Angstrom s cm2)...    None
# 20  [1.4716896302732866e-15 erg / (Angstrom s cm2)...    None
# 21  [3.5085652679974346e-15 erg / (Angstrom s cm2)...    None
# 22  [5.124037907942307e-09 erg / (Angstrom s cm2),...    None
# 23  [7.195592411183563e-09 erg / (Angstrom s cm2),...    None
# 24  [9.63388324409035e-15 erg / (Angstrom s cm2), ...    None
# 25  [5.152730988284242e-09 erg / (Angstrom s cm2),...    None
# 26  [5.152730988284242e-09 erg / (Angstrom s cm2),...    None
# 27  [1.3525695168729782e-12 erg / (Angstrom s cm2)...    None
# 28  [5.5481324408358305e-15 erg / (Angstrom s cm2)...    None
# 29  [5.504779145472877e-15 erg / (Angstrom s cm2),...    None
# 30  [1.5418678944326007e-10 erg / (Angstrom s cm2)...    None
# 31  [9.642340863131392e-15 erg / (Angstrom s cm2),...    None
# 32  [1.1126062084868046e-14 erg / (Angstrom s cm2)...    None
# 33  [5.546637442693923e-15 erg / (Angstrom s cm2),...    None
# 34  [3.508632933132529e-15 erg / (Angstrom s cm2),...    None
# 35  [7.85753943495468e-15 erg / (Angstrom s cm2), ...    None
# 36  [7.856148704155391e-15 erg / (Angstrom s cm2),...    None
# 37  [4.3378758290994255e-15 erg / (Angstrom s cm2)...    None
# 38  [7.232671737449716e-09 erg / (Angstrom s cm2),...    None
# 39  [7.2143625956060305e-09 erg / (Angstrom s cm2)...    None
# 40  [7.379815769393872e-09 erg / (Angstrom s cm2),...    None
#
#                                            H2line_idx  \
# 0   [469, 486, 4, 231, 483, 11, 242, 433, 500, 153...
# 1   [17378, 17958, 1626, 9308, 17840, 1863, 9679, ...
# 2   [17375, 17955, 1623, 9305, 17837, 1860, 9676, ...
# 3   [496, 513, 31, 258, 510, 38, 269, 460, 527, 18...
# 4   [458, 475, 220, 472, 0, 231, 422, 489, 142, 26...
# 5   [17380, 17960, 1628, 9310, 17842, 1865, 9681, ...
# 6   [17377, 17957, 1625, 9307, 17839, 1862, 9678, ...
# 7   [17374, 17954, 1622, 9304, 17836, 1859, 9675, ...
# 8   [28055, 28346, 29628, 31143, 30033, 26412, 267...
# 9   [15167, 15747, 7090, 15629, 7461, 13936, 16212...
# 10  [17367, 17947, 1615, 9297, 17829, 1852, 9668, ...
# 11  [17366, 17946, 1614, 9296, 17828, 1851, 9667, ...
# 12  [17365, 17945, 1613, 9295, 17827, 1850, 9666, ...
# 13  [17384, 17964, 1632, 9314, 17846, 1869, 9685, ...
# 14  [17379, 17959, 1627, 9309, 17841, 1864, 9680, ...
# 15  [502, 519, 37, 264, 516, 44, 275, 466, 533, 18...
# 16  [462, 479, 224, 476, 4, 235, 426, 493, 146, 26...
# 17  [17379, 17959, 1627, 9309, 17841, 1864, 9680, ...
# 18  [17376, 17956, 1624, 9306, 17838, 1861, 9677, ...
# 19  [17024, 17604, 1264, 8950, 17486, 1501, 9320, ...
# 20  [44610, 45190, 28054, 36536, 45072, 28345, 369...
# 21  [17372, 17952, 1620, 9302, 17834, 1857, 9673, ...
# 22  [499, 516, 34, 261, 513, 41, 272, 463, 530, 18...
# 23  [526, 543, 61, 288, 540, 68, 299, 490, 557, 21...
# 24  [17383, 17963, 1631, 9313, 17845, 1868, 9684, ...
# 25  [509, 526, 44, 271, 523, 51, 282, 473, 540, 19...
# 26  [509, 526, 44, 271, 523, 51, 282, 473, 540, 19...
# 27  [25341, 25727, 14862, 19972, 25648, 15020, 202...
# 28  [17374, 17954, 1622, 9304, 17836, 1859, 9675, ...
# 29  [17374, 17954, 1622, 9304, 17836, 1859, 9675, ...
# 30  [25401, 25787, 14922, 20032, 25708, 15080, 202...
# 31  [17364, 17944, 1612, 9294, 17826, 1849, 9665, ...
# 32  [17384, 17964, 1632, 9314, 17846, 1869, 9685, ...
# 33  [17363, 17943, 1611, 9293, 17825, 1848, 9664, ...
# 34  [17371, 17951, 1619, 9301, 17833, 1856, 9672, ...
# 35  [17375, 17955, 1623, 9305, 17837, 1860, 9676, ...
# 36  [17375, 17955, 1623, 9305, 17837, 1860, 9676, ...
# 37                                                 []
# 38  [499, 516, 34, 261, 513, 41, 272, 463, 530, 18...
# 39  [504, 521, 39, 266, 518, 46, 277, 468, 535, 18...
# 40  [493, 510, 28, 255, 507, 35, 266, 457, 524, 17...
#
#                                             [nu', J']  \
# 0   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 1   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 2   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 3   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 4   [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 5   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 6   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 7   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 8   [[4,13], [3,16], [1,4], [1,4], [3,0], [0,1], [...
# 9   [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 10  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 11  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 12  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 13  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 14  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 15  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 16  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 17  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 18  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 19  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 20  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 21  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 22  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 23  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 24  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 25  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 26  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 27  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 28  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 29  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 30  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 31  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 32  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 33  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 34  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 35  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 36  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 37                                                 []
# 38  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 39  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 40  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
#
#                                               labline  \
# 0   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 1   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 2   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 3   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 4   [1608.33, 1615.43, 1509.45, 1613.99, 1418.23, ...
# 5   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 6   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 7   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 8   [1415.33, 1418.23, 1431.01, 1446.12, 1435.05, ...
# 9   [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 10  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 11  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 12  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 13  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 14  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 15  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 16  [1608.33, 1615.43, 1509.45, 1613.99, 1418.23, ...
# 17  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 18  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 19  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 20  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 21  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 22  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 23  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 24  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 25  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 26  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 27  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 28  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 29  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 30  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 31  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 32  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 33  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 34  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 35  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 36  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 37                                                 []
# 38  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 39  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 40  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
#
#                                       transition_prob
# 0   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 1   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 2   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 3   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 4   [0.139, 0.125, 0.023, 0.092, 0.05, 0.057, 0.12...
# 5   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 6   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 7   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 8   [0.037, 0.05, 0.058, 0.083, 0.118, 0.141, 0.12...
# 9   [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 10  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 11  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 12  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 13  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 14  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 15  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 16  [0.139, 0.125, 0.023, 0.092, 0.05, 0.057, 0.12...
# 17  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 18  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 19  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 20  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 21  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 22  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 23  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 24  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 25  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 26  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 27  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 28  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 29  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 30  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 31  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 32  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 33  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 34  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 35  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 36  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 37                                                 []
# 38  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 39  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 40  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...

# %%
x1dsum_files = glob(os.path.join('HST', 'anonymous37222', '*x1dsum.fits'))
all_spectra = spectrum(x1dsum_files, linelist_file='HST/emission_lines.csv', dataDir='HST/')
all_spectra.coaddwave(all_spectra.spec_df, columns = ['obsdate', 'filter'])
all_spectra.H2lines_fromspectrum(all_spectra.spec_df)
# Out:
#                                     filename     obsdate instrument filter  \
# 0   HST/anonymous37222/lbgj02060_x1dsum.fits  2011-07-20        COS  G130M
# 1   HST/anonymous37222/lbgj53080_x1dsum.fits  2012-02-28        COS  G160M
# 2   HST/anonymous37222/leit1j040_x1dsum.fits  2021-08-17        COS  G160M
# 3   HST/anonymous37222/leit1n040_x1dsum.fits  2021-08-21        COS  G160M
# 4   HST/anonymous37222/leph1h040_x1dsum.fits  2022-08-14        COS  G160M
# 5   HST/anonymous37222/leit1e040_x1dsum.fits  2021-08-12        COS  G160M
# 6   HST/anonymous37222/leit1g030_x1dsum.fits  2021-08-14        COS  G160M
# 7   HST/anonymous37222/lbgj53040_x1dsum.fits  2012-02-28        COS  G130M
# 8   HST/anonymous37222/leso2c010_x1dsum.fits  2022-06-16        COS  G160M
# 9   HST/anonymous37222/leit1d030_x1dsum.fits  2021-08-11        COS  G160M
# 10  HST/anonymous37222/leph1k040_x1dsum.fits  2022-08-17        COS  G160M
# 11  HST/anonymous37222/leph1d040_x1dsum.fits  2022-08-11        COS  G160M
# 12  HST/anonymous37222/leso2d020_x1dsum.fits  2022-06-16        COS  G130M
# 13  HST/anonymous37222/leit1m040_x1dsum.fits  2021-08-20        COS  G160M
# 14  HST/anonymous37222/lephae040_x1dsum.fits  2022-08-24        COS  G160M
# 15  HST/anonymous37222/leph1j040_x1dsum.fits  2022-08-16        COS  G160M
# 16  HST/anonymous37222/lephad040_x1dsum.fits  2022-08-23        COS  G160M
# 17  HST/anonymous37222/leph1n040_x1dsum.fits  2022-08-20        COS  G160M
# 18  HST/anonymous37222/leph1l030_x1dsum.fits  2022-08-18        COS  G160M
# 19  HST/anonymous37222/lbgj020b0_x1dsum.fits  2011-07-20        COS  G160M
# 20  HST/anonymous37222/leph1c030_x1dsum.fits  2022-08-10        COS  G160M
# 21  HST/anonymous37222/leit1c040_x1dsum.fits  2021-08-10        COS  G160M
# 22  HST/anonymous37222/leit1h030_x1dsum.fits  2021-08-15        COS  G160M
# 23  HST/anonymous37222/leph1f040_x1dsum.fits  2022-08-13        COS  G160M
# 24  HST/anonymous37222/leph1i030_x1dsum.fits  2022-08-15        COS  G160M
# 25  HST/anonymous37222/leph1m040_x1dsum.fits  2022-08-19        COS  G160M
# 26  HST/anonymous37222/leit1i030_x1dsum.fits  2021-08-16        COS  G160M
# 27  HST/anonymous37222/leit1k040_x1dsum.fits  2021-08-18        COS  G160M
# 28  HST/anonymous37222/leit1f030_x1dsum.fits  2021-08-13        COS  G160M
#
#                    dispfile                                LSFfile  cenwave  \
# 0   HST/05i1639ml_disp.fits  HST/aa_LSFTable_G130M_1309_LP1_cn.dat     1309
# 1   HST/05i1639ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP1_cn.dat     1589
# 2   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 3   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 4   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 5   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 6   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 7   HST/05i1639ml_disp.fits  HST/aa_LSFTable_G130M_1291_LP1_cn.dat     1291
# 8   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 9   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 10  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 11  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 12  HST/5992009ol_disp.fits  HST/aa_LSFTable_G130M_1291_LP5_cn.dat     1291
# 13  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 14  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 15  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 16  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 17  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 18  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 19  HST/05i1639ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP1_cn.dat     1623
# 20  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 21  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 22  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 23  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 24  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 25  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 26  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 27  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1623_LP4_cn.dat     1623
# 28  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
#
#                                            wavelength  \
# 0   [1143.9478185093035 Angstrom, 1143.95778546951...
# 1   [1386.2769487823698 Angstrom, 1386.28918573199...
# 2   [1421.2507669904041 Angstrom, 1421.26301555731...
# 3   [1421.2495047660054 Angstrom, 1421.26175332201...
# 4   [1421.252026333801 Angstrom, 1421.264274911534...
# 5   [1421.2530224847878 Angstrom, 1421.26527107114...
# 6   [1385.9926535426373 Angstrom, 1386.00489328013...
# 7   [1124.9096635174221 Angstrom, 1124.91962690073...
# 8   [1386.075555441118 Angstrom, 1386.087795910712...
# 9   [1385.9941396590698 Angstrom, 1386.00637941009...
# 10  [1421.250823324304 Angstrom, 1421.263071891649...
# 11  [1421.254063552068 Angstrom, 1421.266312147713...
# 12  [1124.1220811272192 Angstrom, 1124.13204848542...
# 13  [1421.2497910066452 Angstrom, 1421.26203956501...
# 14  [1421.2488942629827 Angstrom, 1421.26114281391...
# 15  [1421.251197231767 Angstrom, 1421.263445802492...
# 16  [1421.2490731986265 Angstrom, 1421.26132175097...
# 17  [1421.249797536383 Angstrom, 1421.262046095076...
# 18  [1385.9909696082839 Angstrom, 1386.00320933088...
# 19  [1421.2426308057047 Angstrom, 1421.25487447368...
# 20  [1385.9951835939507 Angstrom, 1386.00742335376...
# 21  [1421.254196584923 Angstrom, 1421.266445181324...
# 22  [1385.9921658835162 Angstrom, 1386.00440561677...
# 23  [1421.2530339201037 Angstrom, 1421.26528250643...
# 24  [1385.9921428581877 Angstrom, 1386.00438259114...
# 25  [1421.2501191586277 Angstrom, 1421.26236772004...
# 26  [1385.9916804390439 Angstrom, 1386.00392016811...
# 27  [1421.250438441241 Angstrom, 1421.262687005296...
# 28  [1385.9931276253203 Angstrom, 1386.00536736705...
#
#                                                  flux  \
# 0   [-6.211189500925533e-17 erg / (Angstrom s cm2)...
# 1   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 2   [6.104225441647611e-15 erg / (Angstrom s cm2),...
# 3   [1.2704321293563937e-14 erg / (Angstrom s cm2)...
# 4   [7.816415801042917e-15 erg / (Angstrom s cm2),...
# 5   [9.036448651692967e-15 erg / (Angstrom s cm2),...
# 6   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 7   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 8   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 9   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 10  [4.421725329470133e-15 erg / (Angstrom s cm2),...
# 11  [-2.957552869772527e-17 erg / (Angstrom s cm2)...
# 12  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 13  [8.544234773075823e-15 erg / (Angstrom s cm2),...
# 14  [9.00888619710672e-15 erg / (Angstrom s cm2), ...
# 15  [3.9723745587164904e-15 erg / (Angstrom s cm2)...
# 16  [6.921313883776253e-15 erg / (Angstrom s cm2),...
# 17  [1.0880142169956368e-14 erg / (Angstrom s cm2)...
# 18  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 19  [7.428045243004162e-15 erg / (Angstrom s cm2),...
# 20  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 21  [4.736898099985594e-15 erg / (Angstrom s cm2),...
# 22  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 23  [9.827029141049102e-15 erg / (Angstrom s cm2),...
# 24  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 25  [7.847438214885928e-15 erg / (Angstrom s cm2),...
# 26  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 27  [8.536568923043122e-15 erg / (Angstrom s cm2),...
# 28  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
#
#                                               fluxerr  \
# 0   [4.574151266699581e-15 erg / (Angstrom s cm2),...
# 1   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 2   [5.5665447423026935e-15 erg / (Angstrom s cm2)...
# 3   [6.983943851565451e-15 erg / (Angstrom s cm2),...
# 4   [7.348683754258418e-15 erg / (Angstrom s cm2),...
# 5   [6.293201513186521e-15 erg / (Angstrom s cm2),...
# 6   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 7   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 8   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 9   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 10  [5.357499522124684e-15 erg / (Angstrom s cm2),...
# 11  [4.119783564383839e-15 erg / (Angstrom s cm2),...
# 12  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 13  [6.188399735710151e-15 erg / (Angstrom s cm2),...
# 14  [6.532031193179931e-15 erg / (Angstrom s cm2),...
# 15  [5.240186208078233e-15 erg / (Angstrom s cm2),...
# 16  [6.0181871815992125e-15 erg / (Angstrom s cm2)...
# 17  [6.910902657016393e-15 erg / (Angstrom s cm2),...
# 18  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 19  [2.1946829076202424e-14 erg / (Angstrom s cm2)...
# 20  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 21  [5.222956335908761e-15 erg / (Angstrom s cm2),...
# 22  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 23  [6.622058971350219e-15 erg / (Angstrom s cm2),...
# 24  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 25  [6.157208622747031e-15 erg / (Angstrom s cm2),...
# 26  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 27  [6.194585743376239e-15 erg / (Angstrom s cm2),...
# 28  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
#
#                                               segment  \
# 0   [[1297.231549843736, 1460.5289430618789], [114...
# 1   [[1574.475576544502, 1775.0252147764359], [138...
# 2   [[1609.5822888340551, 1810.313848989957], [142...
# 3   [[1609.5808640557434, 1810.3122455943226], [14...
# 4   [[1609.5837552013058, 1810.3154927026615], [14...
# 5   [[1609.5848743233983, 1810.316753179727], [142...
# 6   [[1574.1753619262686, 1774.8271628899083], [13...
# 7   [[1278.1908850506225, 1441.4677056605317], [11...
# 8   [[1574.2695000413048, 1774.9333026340148], [13...
# 9   [[1574.177039290039, 1774.8290620852715], [138...
# 10  [[1609.5823110742344, 1810.313878321534], [142...
# 11  [[1609.5861381699028, 1810.3181692097505], [14...
# 12  [[1277.3619829723048, 1440.67858986322], [1124...
# 13  [[1609.5812554176673, 1810.3126756537506], [14...
# 14  [[1609.5802403789269, 1810.3115387103865], [14...
# 15  [[1609.582826716216, 1810.3144493675713], [142...
# 16  [[1609.5803996806708, 1810.3117211835993], [14...
# 17  [[1609.5812287155782, 1810.3126541754273], [14...
# 18  [[1574.1734227994093, 1774.8249795589593], [13...
# 19  [[1609.5728914806764, 1810.1670567665303], [14...
# 20  [[1574.1782031017756, 1774.8303699895666], [13...
# 21  [[1609.586167640663, 1810.3182110654668], [142...
# 22  [[1574.1747588329204, 1774.8264902607607], [13...
# 23  [[1609.5848960343299, 1810.3167744590412], [14...
# 24  [[1574.1747250689384, 1774.8264515686096], [13...
# 25  [[1609.5815802772663, 1810.3130503200541], [14...
# 26  [[1574.174218929461, 1774.8258818508884], [138...
# 27  [[1609.5819599789054, 1810.3134733167517], [14...
# 28  [[1574.1758709162705, 1774.8277413948108], [13...
#
#                                            H2line_idx  \
# 0   [28232, 28523, 29805, 31321, 30211, 26589, 327...
# 1   [19150, 19730, 2374, 10066, 19612, 2611, 10437...
# 2   [15274, 16331, 7201, 16096, 7571, 14043, 17260...
# 3   [15274, 16331, 7201, 16096, 7572, 14043, 17260...
# 4   [15273, 16331, 7201, 16096, 7571, 14043, 17260...
# 5   [15273, 16331, 7201, 16095, 7571, 14043, 17260...
# 6   [19173, 19752, 2397, 10087, 19635, 2634, 10458...
# 7   [30144, 30435, 31718, 32123, 28501, 28872, 320...
# 8   [19165, 19745, 2390, 10079, 19627, 2627, 10450...
# 9   [19173, 19752, 2397, 10086, 19635, 2634, 10457...
# 10  [15274, 16331, 7201, 16096, 7571, 14043, 17260...
# 11  [15273, 16330, 7200, 16095, 7571, 14043, 17259...
# 12  [30224, 30515, 31797, 32202, 28581, 28952, 321...
# 13  [15274, 16331, 7201, 16096, 7572, 14043, 17260...
# 14  [15274, 16331, 7201, 16096, 7572, 14043, 17260...
# 15  [15274, 16331, 7201, 16096, 7571, 14043, 17260...
# 16  [15274, 16331, 7201, 16096, 7572, 14043, 17260...
# 17  [15274, 16331, 7201, 16096, 7572, 14043, 17260...
# 18  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 19  [15280, 16339, 7204, 16104, 7575, 14049, 17269...
# 20  [19172, 19752, 2397, 10086, 19635, 2634, 10457...
# 21  [15273, 16330, 7200, 16095, 7571, 14043, 17259...
# 22  [19173, 19752, 2397, 10087, 19635, 2634, 10458...
# 23  [15273, 16331, 7201, 16095, 7571, 14043, 17260...
# 24  [19173, 19752, 2397, 10087, 19635, 2634, 10458...
# 25  [15274, 16331, 7201, 16096, 7571, 14043, 17260...
# 26  [19173, 19752, 2397, 10087, 19635, 2634, 10458...
# 27  [15274, 16331, 7201, 16096, 7571, 14043, 17260...
# 28  [19173, 19752, 2397, 10087, 19635, 2634, 10457...
#
#                                             [nu', J']  \
# 0   [[4,13], [3,16], [1,4], [1,4], [3,0], [0,1], [...
# 1   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 2   [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 3   [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 4   [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 5   [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 6   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 7   [[4,13], [3,16], [1,4], [3,0], [0,1], [0,2], [...
# 8   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 9   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 10  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 11  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 12  [[4,13], [3,16], [1,4], [3,0], [0,1], [0,2], [...
# 13  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 14  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 15  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 16  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 17  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 18  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 19  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 20  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 21  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 22  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 23  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 24  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 25  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 26  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 27  [[3,13], [3,13], [4,13], [4,13], [3,16], [3,16...
# 28  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
#
#                                               labline  \
# 0   [1415.33, 1418.23, 1431.01, 1446.12, 1435.05, ...
# 1   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 2   [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 3   [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 4   [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 5   [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 6   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 7   [1415.33, 1418.23, 1431.01, 1435.05, 1398.95, ...
# 8   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 9   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 10  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 11  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 12  [1415.33, 1418.23, 1431.01, 1435.05, 1398.95, ...
# 13  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 14  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 15  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 16  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 17  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 18  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 19  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 20  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 21  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 22  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 23  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 24  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 25  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 26  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 27  [1608.33, 1615.43, 1509.45, 1613.99, 1513.99, ...
# 28  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
#
#                                       transition_prob
# 0   [0.037, 0.05, 0.058, 0.083, 0.118, 0.141, 0.08...
# 1   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 2   [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 3   [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 4   [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 5   [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 6   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 7   [0.037, 0.05, 0.058, 0.118, 0.141, 0.126, 0.06...
# 8   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 9   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 10  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 11  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 12  [0.037, 0.05, 0.058, 0.118, 0.141, 0.126, 0.06...
# 13  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 14  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 15  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 16  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 17  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 18  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 19  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 20  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 21  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 22  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 23  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 24  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 25  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 26  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 27  [0.139, 0.125, 0.023, 0.092, 0.057, 0.122, 0.0...
# 28  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...

# %% [markdown]
# # Compile properties of individual lines

# %%
all_spectra.spec_df = all_spectra.spec_df[all_spectra.spec_df["[nu', J']"].notna() & (all_spectra.spec_df["[nu', J']"].apply(len) > 0)] #remove the spectra (coadded for one observation date) that don't have any H2 lines
line_df = all_spectra.get_lines(all_spectra.spec_df) #rearrange df by progressions, not obsdate

# %%
cspec_spectra.spec_df = cspec_spectra.spec_df[cspec_spectra.spec_df["[nu', J']"].notna() & (cspec_spectra.spec_df["[nu', J']"].apply(len) > 0)] #remove the spectra (coadded for one observation date) that don't have any H2 lines
line_df = cspec_spectra.get_lines(cspec_spectra.spec_df) #rearrange df by progressions, not obsdate
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 cspec_spectra.spec_df = cspec_spectra.spec_df[cspec_spectra.spec_df["[nu', J']"].notna() & (cspec_spectra.spec_df["[nu', J']"].apply(len) > 0)] #remove the spectra (coadded for one observation date) that don't have any H2 lines
# ----> 2 line_df = cspec_spectra.get_lines(cspec_spectra.spec_df) #rearrange df by progressions, not obsdate
#
# File ~/scripts_by_me/research24/empirical_functions.py:499, in spectrum.get_lines(self, df)
#     497                 for key in self.lineInfo_keys:
#     498                     line_dict[key].append(np.array(row[key])[targ_idx[i]])
# --> 499 line_df = pd.DataFrame(line_dict)
#     500 return line_df
#
# File ~/scripts_by_me/research24/astrovenv/lib/python3.10/site-packages/pandas/core/frame.py:782, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     776     mgr = self._init_mgr(
#     777         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     778     )
#     780 elif isinstance(data, dict):
#     781     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 782     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     783 elif isinstance(data, ma.MaskedArray):
#     784     from numpy.ma import mrecords
#
# File ~/scripts_by_me/research24/astrovenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~/scripts_by_me/research24/astrovenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File ~/scripts_by_me/research24/astrovenv/lib/python3.10/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# # Look for contaminated lines
# Transitions we have:
# {'[0,3]', '[2,12]', '[0,2]', '[1,7]', '[4,13]', '[0,1]', '[3,16]', '[2,15]', '[1,4]', '[3,0]', '[4,4]', '[3,13]'}
#
# Remove the noisy lines with very low SNR. This was done by eye, not an SNR cut.

# %%
exclude_lines = {
    "[0,1]": {
        "dates": ["2022-08-11", "2022-08-24", "2011-07-20", "2021-08-11", 
                  "2021-08-11", "2021-08-11", "2011-07-20", "2012-02-28", 
                  "2012-02-28", "2021-08-16", "2022-08-14", "2022-08-11",
                  "2022-08-11"],
        "wavelengths": [1460.17, 1521.59, 1521.59, 1398.95,
                        1460.17, 1521.59, 1398.95, 1521.59, 
                        1398.95, 1521.59, 1521.59, 1398.95, 
                        1521.59]
    },
    "[0,2]": {
        "dates": ["2022-08-11", "2021-08-11", "2021-08-11", "2012-02-28", "All", "All"],
        "wavelengths": [1463.83, 1402.65, 1463.83, 1402.65, 1525.15, 1402.65] #1402.65 line contaminated by Si IV
    },
    "[1,4]": {
        "dates": ["2022-08-11", "2021-08-11", "2021-08-11", "2021-08-11", "2021-08-11"],
        "wavelengths": [1431.01, 1431.01, 1446.12, 1489.57, 1504.76]
    },
    "[3,0]": {
        "dates": [
            "2021-08-10", "2021-08-11", "2021-08-11", "2021-08-12",
            "2022-08-11", "2022-08-11", "2022-08-13", "2012-02-28",
            "All"
        ],
        "wavelengths": [
            1636.34, 1591.32, 1636.34, 1636.34,
            1591.32, 1636.34, 1591.32, 1591.32,
            1435.05
        ]
    },
    "[1,7]": {
        "dates": ["All", "All", "2022-08-11", "2022-08-11", "2021-08-11", "2021-08-11"],
        "wavelengths": [1556.87, 1524.65, 1467.08, 1500.45, 1467.08, 1500.45]
    },
    "[2,12]": {
        'dates': ['2021-08-18', '2021-08-18', '2022-06-16', '2022-08-11', 
                  '2022-08-11', '2021-08-20', '2011-07-20', '2021-08-11', 
                  '2021-08-11', '2012-02-28', '2021-08-12', "All", "All"],
        "wavelengths": [1555.89, 1588.8, 1555.89, 1555.89, 
                        1588.8, 1555.89, 1588.8, 1555.89, 
                        1588.8, 1555.89, 1555.89, 1434.54, 1453.1]
    },
    "[4,13]": {
        "dates": [
            "2011-07-20", "All", "2021-08-10", "2021-08-11",
            "2021-08-14", "2021-08-16", "2021-08-17", "2022-08-11",
            "2022-08-13", "2022-08-24", "2022-06-16", "All"
        ],
        "wavelengths": [
            1415.33, 1509.45, 1415.33, 1415.33,
            1415.33, 1415.33, 1415.33, 1415.33,
            1415.33, 1415.33, 1415.33, 1613.99
        ]
    },
    "[3,13]": {
        "dates": [
            "All", "2012-02-28", "2021-08-11", "2022-08-11", "2022-08-15",
            "2022-08-16", "2022-08-17", "2022-08-18", "2022-08-20", "2022-08-23",
            "2022-08-24", "2022-06-16"
        ],
        "wavelengths": [
            1615.43, 1608.33, 1608.33, 1608.33, 1608.33,
            1608.33, 1608.33, 1608.33, 1608.33, 1608.33,
            1608.33, 1608.33
        ]
    },
    "[4,4]": {
        "dates": ["All", "2021-08-10", "2021-08-11", "2022-08-11", "2022-08-11", "All"],
        "wavelengths": [1477.05, 1613.72, 1613.72, 1613.72, 1477.05, 1526.55]
    },
    "[0,3]": {
        "dates": [
            "All", "2021-08-11", "2021-08-20", "2021-08-11", "2021-08-11",
            "2022-06-16", "2022-08-11", "2022-08-24", "2022-08-16",
            "2011-07-20", "2022-08-23", "2012-02-28", "2021-08-21",
            "2022-08-19", "2022-08-19", "2022-08-12", "2022-06-16",
            "2022-08-14", "2022-08-18", "2021-08-17"

        ],
        "wavelengths": [
            1395.2, 1468.39, 1407.29, 1407.29, 1468.39,
            1468.39, 1468.39, 1468.39, 1407.29,
            1468.39, 1468.39, 1468.39, 1407.29,
            1407.29, 1468.39, 1407.29, 1407.29,
            1468.39, 1468.39, 1468.39
        ]
    }
}

# %%
# exclude bad/contaminated lines from coadding
bad_transitions = ['[3,16]', '[4,0]', '[3,13]', '[2,15]'] #938 -> 426 lines in line_df
bad_transitions_mask = ~line_df['transition'].isin(bad_transitions)
line_df = line_df[bad_transitions_mask]

contaminated = []
for transition in exclude_lines.keys():
    dates = exclude_lines[transition]['dates']
    lines_ex = exclude_lines[transition]['wavelengths']
    for d, w in zip(dates, lines_ex):
        if d == "All":
            exclude_idx = line_df.index[(line_df['transition']==transition)&(line_df['labline']==w)].tolist()
        else:
            exclude_idx = line_df.index[(line_df['transition']==transition)&(line_df['labline']==w)&(line_df['obsdate']==d)].tolist()
        contaminated.extend(exclude_idx)

line_df = line_df.drop(index=contaminated)

line_df = line_df[line_df['obsdate']!='2021-08-11']
#Drop duplicates
line_df = line_df[~line_df.duplicated(['obsdate', 'transition', 'labline'])].reset_index(drop=True)

# %%
#Separate out blue transitions
blue_transitions = {'[4,13]', '[4,4]'}
mask = line_df['transition'].isin(blue_transitions)
blue_df = line_df[mask].copy() #146 lines
all_spectra.coaddwave(blue_df, columns=['labline', 'obsdate']) #39 lines

# %%
#Separate out red transitions
red_transitions = {'[2,12]', '[0,3]'}
red_df = line_df[line_df['transition'].isin(red_transitions)].copy() #130 lines
all_spectra.coaddwave(red_df, columns=['labline', 'obsdate']) #76 lines

# %%
#Remove blue and red transitions from main df
br_transitions = ['[2,12]', '[4,13]', '[4,4]', '[0,3]']
bad_transitions_mask = ~line_df['transition'].isin(br_transitions)
line_df = line_df[bad_transitions_mask].reset_index(drop=True)
all_spectra.coaddwave(line_df, columns=['labline', 'obsdate']) #236 lines

# %%
# labline: mask array
line_mask_dict = {
    1453.1:200,
    1555.89:[75,175],
    1463.83:200,
    1613.72:[75,200],
    1415.33:180,
    1407.29:200,
    1468.39:[75,299], #mask out MgII transition at 1466.55
    1407.29: [75,250],
    1435.05: [80,299], #High velocity component
    1636.34: [75,190]
}
def mask_contamination(labline, mask_dict):
    mask_idx = mask_dict[labline]
    if isinstance(mask_idx, list):
        mask=np.ones(300, dtype=bool)
        mask[mask_idx[0]:mask_idx[1]] = False
        return mask
    else:
        mask=np.zeros(300, dtype=bool)
        mask[mask_idx:] = True
        return mask

def get_continuum(row):
    if row['labline'] in line_mask_dict.keys():
        mask = mask_contamination(row['labline'], line_mask_dict)
        x_masked, y_masked = row['wavelength'][~mask], row['flux'][~mask]
        #pull out background
        x_fit, y_fit = x_masked[:40].value, y_masked[:40].value
    else:
        x_fit, y_fit = np.concatenate(row['wavelength'][:40].value, row['wavelength'][-20:].value) , np.concatenate(row['flux'][:40].value, row['flux'][-20:].value)

    #fit to background
    p = np.polyfit(x_fit, y_fit, 1)
    #get continuum over the whole line
    continuum_fluxes = p[1] + (row['wavelength'].value*p[0])
    return continuum_fluxes

# %% [markdown]
# # Continuum Subtract
# Want to do this locally to each line because a lot of things affect the shape of the continuum, can't just have a simple physical model

# %%
import matplotlib.pyplot as plt

# %%
#1st order polynomial like Keri did in radiative models, simple np.polyfit
for line in line_mask_dict.keys():
    #test case
    sub_df = line_df[line_df['labline']==line]
    if len(sub_df)>1:
        row = sub_df.iloc[0]
    elif len(sub_df)==1:
        row = sub_df
    else:
        continue
    
    #row = line_df.iloc[0]
    #mask out line contamination
    if row['labline'] in line_mask_dict.keys():
        continuum_fluxes = get_continuum(row)
        plt.plot(row['wavelength'], row['flux'])
        #plt.plot(x_masked, y_masked)
        #plt.plot(row['wavelength'][~mask][:40], row['flux'][~mask][:40])
        plt.plot(row['wavelength'], continuum_fluxes)
        transition = row['transition']
        plt.title(f'{line}, {transition}')
        plt.show()

# %% [markdown]
# # Co-add by lablines and by years

# %%
red_df_coadded = all_spectra.coadd_lines(red_df)
blue_df_coadded = all_spectra.coadd_lines(blue_df)
line_df_coadded = all_spectra.coadd_lines(line_df)

# %% [markdown]
# # Model the emission lines and save the parameters

# %%
#build dataframe for convolution information
def make_disp_df(files):
    disptable_info = []
    for file in files:
        disptable = fits.open(file, ignore_missing_simple=True)[1].data
        disptable = disptable[disptable['aperture']=="PSA"]
        cols = {}
        for col in ['SEGMENT', 'CENWAVE', 'OPT_ELEM','COEFF', 'D_TV03', 'D']:
            cols[col] = disptable[col]
        cols['disptab']=file
        disptable_info.append(cols)
    disp_df = pd.DataFrame(disptable_info).set_index('disptab')
    return disp_df

def make_lsf_df(files):
    lsf_info = []
    for file in files:
        # This is the table of all the LSFs: called "lsf"
        # The first column is a list of the wavelengths corresponding to the line profile, so we set our header accordingly
        hs = 0
        lsf = Table.read(file, format="ascii", header_start=hs)

        # This is the range of each LSF in pixels (for FUV from -160 to +160, inclusive)
        # middle pixel of the lsf is considered zero ; center is relative zero
        pix = np.arange(len(lsf)) - len(lsf) // 2  # integer division to yield whole pixels

        # the column names returned as integers.
        lsf_wvlns = np.array([int(float(k)) for k in lsf.keys()])
        lsf_info.append({'lsf_file':file, 'lsf':lsf, 'pix':pix, 'w':lsf_wvlns})
    lsf_df = pd.DataFrame(lsf_info).set_index('lsf_file')
    return lsf_df

disp_df = make_disp_df(set(list(set(line_df['dispfile']))+list(set(blue_df['dispfile']))+list(set(red_df['dispfile']))))
lsf_df = make_lsf_df(set(list(set(line_df['LSFfile']))+list(set(blue_df['LSFfile']))+list(set(red_df['LSFfile']))))

# %%
#disp_df.to_pickle(os.path.join('data','disp_df.pkl'))
#lsf_df.to_pickle(os.path.join('data','lsf_df.pkl'))
disp_df = pd.read_pickle('data/disp_df.pkl')
lsf_df = pd.read_pickle('data/lsf_df.pkl')

# %%
initial_guess_line_df = {
    1521.59: {'amp1':{'init':1e-13, 'min':5e-14, 'max':2e-13},
                     'sig1':{'init':5e-2, 'min':0.02, 'max':0.08},
                     'cen1':{'init':1521.59, 'min':1521.59-0.5, 'max':1521.59+0.5},
                     'amp2':{'init':4e-14, 'min':None, 'max':5e-14},
                     'sig2':{'init':0.1, 'min':0.08, 'max':0.5},
                     'cen2':{'init':1521.59, 'min':1521.59-0.5, 'max':1521.59+0.5},
                     'bgl':{'init':4.8e-14, 'min':None, 'max':None}},

    1463.83: {'amp1':{'init':5e-13, 'min':2e-13, 'max':8e-12},
                     'sig1':{'init':5.5e-2, 'min':4.8e-2, 'max':7e-2},
                     'cen1':{'init':1463.83, 'min':1463.83-0.5, 'max':1463.83+0.5},
                     'amp2':{'init':1.5e-13, 'min':1e-13, 'max':2e-13},
                     'sig2':{'init':1.8e-1, 'min':1.5e-1, 'max':2e-1},
                     'cen2':{'init':1463.83, 'min':1463.83-0.5, 'max':1463.83+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1460.17: {'amp1':{'init':8.5e-13, 'min':3e-13, 'max':9e-13},
                     'sig1':{'init':3e-2, 'min':1.5e-2, 'max':5.6e-2},
                     'cen1':{'init':1460.17, 'min':1460.17-0.5, 'max':1460.17+0.5},
                     'amp2':{'init':7.5e-14, 'min':6e-14, 'max':2.9e-13},
                     'sig2':{'init':1e-1, 'min':5.6e-2, 'max':2e-1},
                     'cen2':{'init':1460.17, 'min':1460.17-0.5, 'max':1460.17+0.5},
                     'bgl':{'init':8e-13, 'min':None, 'max':None}},

    1398.95: {'amp1':{'init':4.5e-13, 'min':3e-13, 'max':7e-13},
                     'sig1':{'init':3e-2, 'min':1e-2, 'max':5.5e-2},
                     'cen1':{'init':1398.95, 'min':1398.95-0.5, 'max':1398.95+0.5},
                     'amp2':{'init':2e-13, 'min':1e-13, 'max':2.9e-13},
                     'sig2':{'init':1e-1, 'min':5.6e-2, 'max':2e-1},
                     'cen2':{'init':1398.95, 'min':1398.95-0.5, 'max':1398.95+0.5},
                     'bgl':{'init':4e-14, 'min':None, 'max':None}},

    1636.34: {'amp1':{'init':1.65e-13, 'min':6.9e-14, 'max':2.5e-13},
                     'sig1':{'init':1e-1, 'min':6e-2, 'max':1.5e-1},
                     'cen1':{'init':1636.34, 'min':1636.34-0.5, 'max':1636.34+0.5},
                     'amp2':{'init':6.5e-14, 'min':6.2e-14, 'max':6.9e-14},
                     'sig2':{'init':5e-2, 'min':3e-2, 'max':6e-2}, #this one the shorter comp. is narrower too
                     'cen2':{'init':1636.34, 'min':1636.34-0.5, 'max':1636.34+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1591.32: {'amp1':{'init':1.75e-13, 'min':9e-14, 'max':3e-13},
                     'sig1':{'init':1.5e-1, 'min':8e-2, 'max':2.5e-1},
                     'cen1':{'init':1591.32, 'min':1591.32-0.5, 'max':1591.32+0.5},
                     'amp2':{'init':6e-14, 'min':5e-14, 'max':8.9e-14},
                     'sig2':{'init':4.5e-2, 'min':1e-2, 'max':8e-2},
                     'cen2':{'init':1591.32, 'min':1591.32-0.5, 'max':1591.32+0.5},
                     'bgl':{'init':7e-14, 'min':None, 'max':None}},

    1431.01: {'amp1':{'init':1e-13, 'min':8e-14, 'max':3.8e-13},
                     'sig1':{'init':5e-2, 'min':4e-2, 'max':7e-2},
                     'cen1':{'init':1431.01, 'min':1431.01-0.5, 'max':1431.01+0.5},
                     'amp2':{'init':8.5e-14, 'min':4e-14, 'max':1.5e-13},
                     'sig2':{'init':1.3e-1, 'min':7e-2, 'max':1.9e-1},
                     'cen2':{'init':1431.01, 'min':1431.01-0.5, 'max':1431.01+0.5},
                     'bgl':{'init':3e-14, 'min':None, 'max':None}},

    1446.12: {'amp1':{'init':6.5e-13, 'min':3e-13, 'max':1e-12},
                     'sig1':{'init':6.3e-2, 'min':5.3e-2, 'max':7e-2},
                     'cen1':{'init':1446.12, 'min':1446.12-0.5, 'max':1446.12+0.5},
                     'amp2':{'init':2e-13, 'min':1e-13, 'max':3e-13},
                     'sig2':{'init':1.5e-1, 'min':7e-2, 'max':3e-1},
                     'cen2':{'init':1446.12, 'min':1446.12-0.5, 'max':1446.12+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1489.57: {'amp1':{'init':6.5e-13, 'min':4e-13, 'max':1.3e-12},
                     'sig1':{'init':6e-2, 'min':5e-2, 'max':7e-2},
                     'cen1':{'init':1489.57, 'min':1489.57-0.5, 'max':1489.57+0.5},
                     'amp2':{'init':1.5e-13, 'min':1e-13, 'max':3e-13},
                     'sig2':{'init':2.3e-1, 'min':1e-1, 'max':3.8e-1},
                     'cen2':{'init':1489.57, 'min':1489.57-0.5, 'max':1489.57+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1504.76: {'amp1':{'init':9e-13, 'min':6e-13, 'max':1.5e-12},
                     'sig1':{'init':6e-2, 'min':4e-2, 'max':8e-2},
                     'cen1':{'init':1504.76, 'min':1504.76-1, 'max':1504.76+0.2},
                     'amp2':{'init':2e-13, 'min':1e-13, 'max':5e-13},
                     'sig2':{'init':1.7e-1, 'min':1e-1, 'max':2.5e-1},
                     'cen2':{'init':1504.76, 'min':1504.76-1, 'max':1504.76+0.2},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1467.08: {'amp1':{'init':2e-13, 'min':1.5e-13, 'max':5e-13},
                     'sig1':{'init':3e-2, 'min':1e-2, 'max':7e-2},
                     'cen1':{'init':1467.08, 'min':1467.08-0.5, 'max':1467.08+0.5},
                     'amp2':{'init':6.8e-14, 'min':5e-14, 'max':1.5e-13},
                     'sig2':{'init':1.3e-1, 'min':1e-1, 'max':2.5e-1},
                     'cen2':{'init':1467.08, 'min':1467.08-0.5, 'max':1467.08+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1500.45: {'amp1':{'init':4e-13, 'min':2e-13, 'max':8e-13},
                     'sig1':{'init':6e-2, 'min':4e-2, 'max':8e-2},
                     'cen1':{'init':1500.45, 'min':1500.45-1, 'max':1500.45+0.2},
                     'amp2':{'init':1.6e-13, 'min':5e-14, 'max':2e-13},
                     'sig2':{'init':1.2e-1, 'min':1e-1, 'max':5e-1},
                     'cen2':{'init':1500.45, 'min':1500.45-1, 'max':1500.45+0.2},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},
}

# %%
# for line in line_df_coadded['labline'].unique():
#     test_df = line_df_coadded[line_df_coadded['labline']==line].copy()
#     guess_fit = ModelFitting(test_df, line_mask_dict, disp_df, lsf_df, verbose=False)
#     if line in initial_guess_line_df:
#         print(f'fitting for line {line}')
#         guess_fit.fit_lines(double_guess = initial_guess_line_df[line])
#     else:
#         print(f'amp error for line {line}')
#         #guess_fit.fit_lines()
#         pass
#     test_df.to_pickle(f'data/test_df_{line}.pkl')

# %%
line_df_coadded = pd.read_pickle('line_df_coadded.pkl')

# %%
#Takes about half an hour on a desktop
# fitting = ModelFitting(line_df_coadded, line_mask_dict, disp_df, lsf_df, verbose=False)
blue_fitting = ModelFitting(blue_df_coadded, line_mask_dict, disp_df, lsf_df, verbose=False)
red_fitting = ModelFitting(red_df_coadded, line_mask_dict, disp_df, lsf_df, verbose=False)
# fitting.fit_lines()
blue_fitting.fit_lines()
red_fitting.fit_lines()
# Out:
# Fitting lines:  14%|█▍        | 1/7 [00:18<01:48, 18.09s/it]
# Warning: redchi=0.465 — errors may be overestimated, no rescaling applied
# Fitting lines:  29%|██▊       | 2/7 [00:30<01:14, 14.91s/it]
# Warning: redchi=0.424 — errors may be overestimated, no rescaling applied
# Fitting lines:  43%|████▎     | 3/7 [00:45<00:59, 14.75s/it]
# Warning: redchi=0.277 — errors may be overestimated, no rescaling applied
# Fitting lines: 100%|██████████| 7/7 [01:53<00:00, 16.15s/it]
# Fitting lines:  92%|█████████▏| 11/12 [03:16<00:16, 16.23s/it]
# Warning: redchi=0.346 — errors may be overestimated, no rescaling applied
# Fitting lines: 100%|██████████| 12/12 [03:33<00:00, 17.81s/it]

# %%
line_df_coadded.to_pickle(os.path.join('data','line_df_coadded_bootstrapped_run2.pkl'))
red_df_coadded.to_pickle(os.path.join('data','red_df_coadded_bootstrapped_run2.pkl'))
blue_df_coadded.to_pickle(os.path.join('data','blue_df_coadded_bootstrapped_run2.pkl'))

# %%
line_df_coadded.to_pickle(os.path.join('data','line_df_coadded.pkl'))
red_df_coadded.to_pickle(os.path.join('data','red_df_coadded.pkl'))
blue_df_coadded.to_pickle(os.path.join('data','blue_df_coadded.pkl'))

# %%
line_df.to_pickle(os.path.join('data','line_df_local.pkl'))
red_df.to_pickle(os.path.join('data','red_df.pkl'))
blue_df.to_pickle(os.path.join('data','blue_df.pkl'))

# %%
#make an SNR cut to remove lines whose fit errors are high. This ensures we keep good fits only.
#first, make the cut based on the single gauss fit. Cut if fit SNR < data SNR
def SNR(signal, noise):
    #normalize the signal
    normsignal = signal/np.max(signal)
    normnoise = noise/np.max(noise)
    return np.mean(normsignal/normnoise)

def snr_mask(df, low, high):
    ratio = df.apply(lambda r: SNR(r['gauss_flux'], r['gauss_fluxerr']) /
                               SNR(r['flux'], r['fluxerr']), axis=1)
    return df[ratio.between(low, high)]

red_df_cut  = snr_mask(red_df,  1.3, 13)
blue_df_cut = snr_mask(blue_df, 1.3, 16)
line_df_cut = snr_mask(line_df, 0.8, 100)

# %% [markdown]
# # Coadd lines in velocity space
# Coadding has to be done after the fits because of the convolution with the COS LSF (takes place in wavelength space).
# Coadding by progression will allow me to reproduced the lyman alpha profile for each observation date.
# If I coadd the emission line data and then fit a gaussian to them, that might give me some baseline parameter estimations.

# %%
shift_all = True
line_prog_df = all_spectra.coaddvel(line_df_cut, columns=['transition', 'obsdate'], shift_all=shift_all)
blue_prog_df = all_spectra.coaddvel(blue_df_cut, columns=['transition'], shift_all=shift_all)
red_prog_df = all_spectra.coaddvel(red_df_cut, columns=['transition'], shift_all=shift_all)
prog_df = pd.concat([line_prog_df, blue_prog_df, red_prog_df], ignore_index=True, sort=False)

# %%
line_prog_df.to_pickle(os.path.join('data','line_prog_df_local.pkl'))
red_prog_df.to_pickle(os.path.join('data','red_prog_df.pkl'))
blue_prog_df.to_pickle(os.path.join('data','blue_prog_df.pkl'))
