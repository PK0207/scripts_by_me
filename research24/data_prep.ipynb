# %%
import os
import numpy as np
import pandas as pd
from glob import glob
from astropy.io import fits
from astropy.table import Table
from empirical_functions import spectrum, ModelFitting

# %% [markdown]
# # Initialize spectrum class with HST files
# The data is interesting, I don't have older data, and the cspec files are weird.

# %%
x1dsum_files = glob(os.path.join('HST', 'anonymous37222', '*x1dsum.fits'))
all_spectra = spectrum(x1dsum_files, linelist_file='HST/emission_lines.csv', dataDir='HST/', convolve=False)
all_spectra.coaddwave(all_spectra.spec_df, columns = ['obsdate', 'filter'])
all_spectra.H2lines_fromspectrum(all_spectra.spec_df)
# Out:
#                                     filename     obsdate instrument filter  \
# 0   HST/anonymous37222/lbgj02040_x1dsum.fits  2011-07-20        COS  G130M
# 1   HST/anonymous37222/lbgj02080_x1dsum.fits  2011-07-20        COS  G160M
# 2   HST/anonymous37222/lbgj53040_x1dsum.fits  2012-02-28        COS  G130M
# 3   HST/anonymous37222/lbgj53080_x1dsum.fits  2012-02-28        COS  G160M
# 4   HST/anonymous37222/leit1c030_x1dsum.fits  2021-08-10        COS  G160M
# 5   HST/anonymous37222/leit1d030_x1dsum.fits  2021-08-11        COS  G160M
# 6   HST/anonymous37222/leit1e030_x1dsum.fits  2021-08-12        COS  G160M
# 7   HST/anonymous37222/leit1f030_x1dsum.fits  2021-08-13        COS  G160M
# 8   HST/anonymous37222/leit1g030_x1dsum.fits  2021-08-14        COS  G160M
# 9   HST/anonymous37222/leit1h030_x1dsum.fits  2021-08-15        COS  G160M
# 10  HST/anonymous37222/leit1i030_x1dsum.fits  2021-08-16        COS  G160M
# 11  HST/anonymous37222/leit1j030_x1dsum.fits  2021-08-17        COS  G160M
# 12  HST/anonymous37222/leit1k030_x1dsum.fits  2021-08-18        COS  G160M
# 13  HST/anonymous37222/leit1m030_x1dsum.fits  2021-08-20        COS  G160M
# 14  HST/anonymous37222/leit1n030_x1dsum.fits  2021-08-21        COS  G160M
# 15  HST/anonymous37222/leph1c030_x1dsum.fits  2022-08-10        COS  G160M
# 16  HST/anonymous37222/leph1d030_x1dsum.fits  2022-08-11        COS  G160M
# 17  HST/anonymous37222/leph1f030_x1dsum.fits  2022-08-13        COS  G160M
# 18  HST/anonymous37222/leph1g030_x1dsum.fits  2022-08-14        COS  G160M
# 19  HST/anonymous37222/leph1i030_x1dsum.fits  2022-08-15        COS  G160M
# 20  HST/anonymous37222/leph1j030_x1dsum.fits  2022-08-16        COS  G160M
# 21  HST/anonymous37222/leph1k030_x1dsum.fits  2022-08-17        COS  G160M
# 22  HST/anonymous37222/leph1l030_x1dsum.fits  2022-08-18        COS  G160M
# 23  HST/anonymous37222/leph1m030_x1dsum.fits  2022-08-19        COS  G160M
# 24  HST/anonymous37222/leph1n030_x1dsum.fits  2022-08-20        COS  G160M
# 25  HST/anonymous37222/lephad030_x1dsum.fits  2022-08-23        COS  G160M
# 26  HST/anonymous37222/lephae030_x1dsum.fits  2022-08-24        COS  G160M
# 27  HST/anonymous37222/leso2c010_x1dsum.fits  2022-06-16        COS  G160M
# 28  HST/anonymous37222/leso2c020_x1dsum.fits  2022-06-16        COS  G130M
#
#                    dispfile                                LSFfile  cenwave  \
# 0   HST/05i1639ml_disp.fits  HST/aa_LSFTable_G130M_1291_LP1_cn.dat     1291
# 1   HST/05i1639ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP1_cn.dat     1589
# 2   HST/05i1639ml_disp.fits  HST/aa_LSFTable_G130M_1291_LP1_cn.dat     1291
# 3   HST/05i1639ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP1_cn.dat     1589
# 4   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 5   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 6   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 7   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 8   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 9   HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 10  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 11  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 12  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 13  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 14  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 15  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 16  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 17  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 18  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 19  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 20  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 21  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 22  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 23  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 24  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 25  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 26  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 27  HST/2bj2256ml_disp.fits  HST/aa_LSFTable_G160M_1589_LP4_cn.dat     1589
# 28  HST/5992009ol_disp.fits  HST/aa_LSFTable_G130M_1291_LP5_cn.dat     1291
#
#                                            wavelength  \
# 0   [1124.7185766387568 Angstrom, 1124.72853832954...
# 1   [1386.0412954067515 Angstrom, 1386.05353027634...
# 2   [1124.9096635174221 Angstrom, 1124.91962690073...
# 3   [1386.2769487823698 Angstrom, 1386.28918573199...
# 4   [1385.9946471407397 Angstrom, 1386.00688689571...
# 5   [1385.9941396590698 Angstrom, 1386.00637941009...
# 6   [1385.9934968299058 Angstrom, 1386.00573657483...
# 7   [1385.9931276253203 Angstrom, 1386.00536736705...
# 8   [1385.9926535426373 Angstrom, 1386.00489328013...
# 9   [1385.9921658835162 Angstrom, 1386.00440561677...
# 10  [1385.9916804390439 Angstrom, 1386.00392016811...
# 11  [1385.9912497641506 Angstrom, 1386.00348948963...
# 12  [1385.9909603061985 Angstrom, 1386.00320002882...
# 13  [1385.9903407572133 Angstrom, 1386.00258047415...
# 14  [1385.9900462627913 Angstrom, 1386.00228597737...
# 15  [1385.9951835939507 Angstrom, 1386.00742335376...
# 16  [1385.9945485462765 Angstrom, 1386.00678830049...
# 17  [1385.993493706029 Angstrom, 1386.005733450934...
# 18  [1385.9929259052471 Angstrom, 1386.00516564510...
# 19  [1385.9921428581877 Angstrom, 1386.00438259114...
# 20  [1385.9917161124404 Angstrom, 1386.00395584173...
# 21  [1385.9913361240272 Angstrom, 1386.00357584994...
# 22  [1385.9909696082839 Angstrom, 1386.00320933088...
# 23  [1385.9906740586073 Angstrom, 1386.00291377859...
# 24  [1385.9903499442378 Angstrom, 1386.00258966149...
# 25  [1385.9896587703408 Angstrom, 1386.00189848125...
# 26  [1385.9894779844765 Angstrom, 1386.00171769397...
# 27  [1386.075555441118 Angstrom, 1386.087795910712...
# 28  [1124.122411192166 Angstrom, 1124.132378553306...
#
#                                                  flux  \
# 0   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 1   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 2   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 3   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 4   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 5   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 6   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 7   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 8   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 9   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 10  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 11  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 12  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 13  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 14  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 15  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 16  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 17  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 18  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 19  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 20  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 21  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 22  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 23  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 24  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 25  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 26  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 27  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 28  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
#
#                                               fluxerr  \
# 0   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 1   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 2   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 3   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 4   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 5   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 6   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 7   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 8   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 9   [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 10  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 11  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 12  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 13  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 14  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 15  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 16  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 17  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 18  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 19  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 20  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 21  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 22  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 23  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 24  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 25  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 26  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 27  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
# 28  [0.0 erg / (Angstrom s cm2), 0.0 erg / (Angstr...
#
#                                               segment  \
# 0   [[1277.973751578046, 1441.2228355636628], [112...
# 1   [[1574.2079430415886, 1774.7234919417112], [13...
# 2   [[1278.1908850506225, 1441.4677056605317], [11...
# 3   [[1574.475576544502, 1775.0252147764359], [138...
# 4   [[1574.1775650550824, 1774.8296525079247], [13...
# 5   [[1574.177039290039, 1774.8290620852715], [138...
# 6   [[1574.1763039542636, 1774.82822680399], [1385...
# 7   [[1574.1758709162705, 1774.8277413948108], [13...
# 8   [[1574.1753619262686, 1774.8271628899083], [13...
# 9   [[1574.1747588329204, 1774.8264902607607], [13...
# 10  [[1574.174218929461, 1774.8258818508884], [138...
# 11  [[1574.1737601978853, 1774.825364228126], [138...
# 12  [[1574.1734280322964, 1774.824985216879], [138...
# 13  [[1574.172712608624, 1774.824176621237], [1385...
# 14  [[1574.1723901491057, 1774.823815425727], [138...
# 15  [[1574.1782031017756, 1774.8303699895666], [13...
# 16  [[1574.1773861913039, 1774.8294612569728], [13...
# 17  [[1574.1763140376165, 1774.8282364555246], [13...
# 18  [[1574.175598677498, 1774.827438367698], [1385...
# 19  [[1574.1747250689384, 1774.8264515686096], [13...
# 20  [[1574.1742425524706, 1774.8259091094505], [13...
# 21  [[1574.1738146602324, 1774.82542578561], [1385...
# 22  [[1574.1734227994093, 1774.8249795589593], [13...
# 23  [[1574.1730855192723, 1774.824599379086], [138...
# 24  [[1574.1726908729697, 1774.824160113908], [138...
# 25  [[1574.1719548807457, 1774.8233200404297], [13...
# 26  [[1574.1717301496085, 1774.8230720927218], [13...
# 27  [[1574.2695000413048, 1774.9333026340148], [13...
# 28  [[1277.3623641485256, 1440.6790191373045], [11...
#
#                                            H2line_idx  \
# 0   [30169, 30460, 31742, 32148, 28525, 28896, 320...
# 1   [19172, 19752, 2394, 10087, 19634, 2631, 10458...
# 2   [30144, 30435, 31718, 32123, 28501, 28872, 320...
# 3   [19150, 19730, 2374, 10066, 19612, 2611, 10437...
# 4   [19173, 19752, 2397, 10086, 19635, 2634, 10457...
# 5   [19173, 19752, 2397, 10086, 19635, 2634, 10457...
# 6   [19173, 19752, 2397, 10087, 19635, 2634, 10457...
# 7   [19173, 19752, 2397, 10087, 19635, 2634, 10457...
# 8   [19173, 19752, 2397, 10087, 19635, 2634, 10458...
# 9   [19173, 19752, 2397, 10087, 19635, 2634, 10458...
# 10  [19173, 19752, 2397, 10087, 19635, 2634, 10458...
# 11  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 12  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 13  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 14  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 15  [19172, 19752, 2397, 10086, 19635, 2634, 10457...
# 16  [19173, 19752, 2397, 10086, 19635, 2634, 10457...
# 17  [19173, 19752, 2397, 10087, 19635, 2634, 10457...
# 18  [19173, 19752, 2397, 10087, 19635, 2634, 10457...
# 19  [19173, 19752, 2397, 10087, 19635, 2634, 10458...
# 20  [19173, 19752, 2397, 10087, 19635, 2634, 10458...
# 21  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 22  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 23  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 24  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 25  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 26  [19173, 19753, 2397, 10087, 19635, 2634, 10458...
# 27  [19165, 19745, 2390, 10079, 19627, 2627, 10450...
# 28  [30224, 30515, 31797, 32202, 28581, 28952, 321...
#
#                                             [nu', J']  \
# 0   [[4,13], [3,16], [1,4], [3,0], [0,1], [0,2], [...
# 1   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 2   [[4,13], [3,16], [1,4], [3,0], [0,1], [0,2], [...
# 3   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 4   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 5   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 6   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 7   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 8   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 9   [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 10  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 11  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 12  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 13  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 14  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 15  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 16  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 17  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 18  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 19  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 20  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 21  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 22  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 23  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 24  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 25  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 26  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 27  [[3,13], [3,13], [4,13], [4,13], [4,13], [3,16...
# 28  [[4,13], [3,16], [1,4], [3,0], [0,1], [0,2], [...
#
#                                               labline  \
# 0   [1415.33, 1418.23, 1431.01, 1435.05, 1398.95, ...
# 1   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 2   [1415.33, 1418.23, 1431.01, 1435.05, 1398.95, ...
# 3   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 4   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 5   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 6   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 7   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 8   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 9   [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 10  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 11  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 12  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 13  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 14  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 15  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 16  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 17  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 18  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 19  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 20  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 21  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 22  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 23  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 24  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 25  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 26  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 27  [1608.33, 1615.43, 1415.33, 1509.45, 1613.99, ...
# 28  [1415.33, 1418.23, 1431.01, 1435.05, 1398.95, ...
#
#                                       transition_prob
# 0   [0.037, 0.05, 0.058, 0.118, 0.141, 0.126, 0.06...
# 1   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 2   [0.037, 0.05, 0.058, 0.118, 0.141, 0.126, 0.06...
# 3   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 4   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 5   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 6   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 7   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 8   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 9   [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 10  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 11  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 12  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 13  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 14  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 15  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 16  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 17  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 18  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 19  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 20  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 21  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 22  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 23  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 24  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 25  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 26  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 27  [0.139, 0.125, 0.037, 0.023, 0.092, 0.05, 0.05...
# 28  [0.037, 0.05, 0.058, 0.118, 0.141, 0.126, 0.06...

# %% [markdown]
# # Compile properties of individual lines

# %%
all_spectra.spec_df = all_spectra.spec_df[all_spectra.spec_df["[nu', J']"].notna() & (all_spectra.spec_df["[nu', J']"].apply(len) > 0)] #remove the spectra (coadded for one observation date) that don't have any H2 lines
line_df = all_spectra.get_lines(all_spectra.spec_df) #rearrange df by progressions, not obsdate

# %% [markdown]
# # Look for contaminated lines
# Transitions we have:
# {'[0,3]', '[2,12]', '[0,2]', '[1,7]', '[4,13]', '[0,1]', '[3,16]', '[2,15]', '[1,4]', '[3,0]', '[4,4]', '[3,13]'}
#
# Remove the noisy lines with very low SNR. This was done by eye, not an SNR cut.

# %%
exclude_lines = {
    "[0,1]": {
        "dates": ["2022-08-11", "2022-08-24", "2011-07-20", "2021-08-11", 
                  "2021-08-11", "2021-08-11", "2011-07-20", "2012-02-28", 
                  "2012-02-28", "2021-08-16", "2022-08-14", "2022-08-11",
                  "2022-08-11"],
        "wavelengths": [1460.17, 1521.59, 1521.59, 1398.95,
                        1460.17, 1521.59, 1398.95, 1521.59, 
                        1398.95, 1521.59, 1521.59, 1398.95, 
                        1521.59]
    },
    "[0,2]": {
        "dates": ["2022-08-11", "2021-08-11", "2021-08-11", "2012-02-28", "All", "All"],
        "wavelengths": [1463.83, 1402.65, 1463.83, 1402.65, 1525.15, 1402.65] #1402.65 line contaminated by Si IV
    },
    "[1,4]": {
        "dates": ["2022-08-11", "2021-08-11", "2021-08-11", "2021-08-11", "2021-08-11"],
        "wavelengths": [1431.01, 1431.01, 1446.12, 1489.57, 1504.76]
    },
    "[3,0]": {
        "dates": [
            "2021-08-10", "2021-08-11", "2021-08-11", "2021-08-12",
            "2022-08-11", "2022-08-11", "2022-08-13", "2012-02-28",
            "All"
        ],
        "wavelengths": [
            1636.34, 1591.32, 1636.34, 1636.34,
            1591.32, 1636.34, 1591.32, 1591.32,
            1435.05
        ]
    },
    "[1,7]": {
        "dates": ["All", "All", "2022-08-11", "2022-08-11", "2021-08-11", "2021-08-11"],
        "wavelengths": [1556.87, 1524.65, 1467.08, 1500.45, 1467.08, 1500.45]
    },
    "[2,12]": {
        'dates': ['2021-08-18', '2021-08-18', '2022-06-16', '2022-08-11', 
                  '2022-08-11', '2021-08-20', '2011-07-20', '2021-08-11', 
                  '2021-08-11', '2012-02-28', '2021-08-12', "All", "All"],
        "wavelengths": [1555.89, 1588.8, 1555.89, 1555.89, 
                        1588.8, 1555.89, 1588.8, 1555.89, 
                        1588.8, 1555.89, 1555.89, 1434.54, 1453.1]
    },
    "[4,13]": {
        "dates": [
            "2011-07-20", "All", "2021-08-10", "2021-08-11",
            "2021-08-14", "2021-08-16", "2021-08-17", "2022-08-11",
            "2022-08-13", "2022-08-24", "2022-06-16", "All"
        ],
        "wavelengths": [
            1415.33, 1509.45, 1415.33, 1415.33,
            1415.33, 1415.33, 1415.33, 1415.33,
            1415.33, 1415.33, 1415.33, 1613.99
        ]
    },
    "[3,13]": {
        "dates": [
            "All", "2012-02-28", "2021-08-11", "2022-08-11", "2022-08-15",
            "2022-08-16", "2022-08-17", "2022-08-18", "2022-08-20", "2022-08-23",
            "2022-08-24", "2022-06-16"
        ],
        "wavelengths": [
            1615.43, 1608.33, 1608.33, 1608.33, 1608.33,
            1608.33, 1608.33, 1608.33, 1608.33, 1608.33,
            1608.33, 1608.33
        ]
    },
    "[4,4]": {
        "dates": ["All", "2021-08-10", "2021-08-11", "2022-08-11", "2022-08-11", "All"],
        "wavelengths": [1477.05, 1613.72, 1613.72, 1613.72, 1477.05, 1526.55]
    },
    "[0,3]": {
        "dates": [
            "All", "2021-08-11", "2021-08-20", "2021-08-11", "2021-08-11",
            "2022-06-16", "2022-08-11", "2022-08-24", "2022-08-16",
            "2011-07-20", "2022-08-23", "2012-02-28", "2021-08-21",
            "2022-08-19", "2022-08-19", "2022-08-12", "2022-06-16",
            "2022-08-14", "2022-08-18", "2021-08-17"

        ],
        "wavelengths": [
            1395.2, 1468.39, 1407.29, 1407.29, 1468.39,
            1468.39, 1468.39, 1468.39, 1407.29,
            1468.39, 1468.39, 1468.39, 1407.29,
            1407.29, 1468.39, 1407.29, 1407.29,
            1468.39, 1468.39, 1468.39
        ]
    }
}

# %%
# exclude bad/contaminated lines from coadding
bad_transitions = ['[3,16]', '[4,0]', '[3,13]', '[2,15]'] #938 -> 426 lines in line_df
bad_transitions_mask = ~line_df['transition'].isin(bad_transitions)
line_df = line_df[bad_transitions_mask]

contaminated = []
for transition in exclude_lines.keys():
    dates = exclude_lines[transition]['dates']
    lines_ex = exclude_lines[transition]['wavelengths']
    for d, w in zip(dates, lines_ex):
        if d == "All":
            exclude_idx = line_df.index[(line_df['transition']==transition)&(line_df['labline']==w)].tolist()
        else:
            exclude_idx = line_df.index[(line_df['transition']==transition)&(line_df['labline']==w)&(line_df['obsdate']==d)].tolist()
        contaminated.extend(exclude_idx)

line_df = line_df.drop(index=contaminated)

line_df = line_df[line_df['obsdate']!='2021-08-11']
#Drop duplicates
line_df = line_df[~line_df.duplicated(['obsdate', 'transition', 'labline'])].reset_index(drop=True)

# %%
#Separate out blue transitions
blue_transitions = {'[4,13]', '[4,4]'}
mask = line_df['transition'].isin(blue_transitions)
blue_df = line_df[mask].copy() #146 lines
all_spectra.coaddwave(blue_df, columns=['labline', 'obsdate']) #39 lines

# %%
#Separate out red transitions
red_transitions = {'[2,12]', '[0,3]'}
red_df = line_df[line_df['transition'].isin(red_transitions)].copy() #130 lines
all_spectra.coaddwave(red_df, columns=['labline', 'obsdate']) #76 lines

# %%
#Remove blue and red transitions from main df
br_transitions = ['[2,12]', '[4,13]', '[4,4]', '[0,3]']
bad_transitions_mask = ~line_df['transition'].isin(br_transitions)
line_df = line_df[bad_transitions_mask].reset_index(drop=True)
all_spectra.coaddwave(line_df, columns=['labline', 'obsdate']) #236 lines

# %% [markdown]
# # Co-add by lablines and by years

# %%
red_df_coadded = all_spectra.coadd_lines(red_df)
blue_df_coadded = all_spectra.coadd_lines(blue_df)
line_df_coadded = all_spectra.coadd_lines(line_df)

# %% [markdown]
# # Model the emission lines and save the parameters

# %%
# labline: mask array
line_mask_dict = {
    1453.1:200,
    1555.89:[75,175],
    1463.83:200,
    1613.72:[75,200],
    1415.33:180,
    1407.29:200,
    1468.39:[75,299], #mask out MgII transition at 1466.55
    1407.29: [75,250],
    1435.05: [80,299], #High velocity component
    1636.34: [75,190]
}

# %%
#build dataframe for convolution information
def make_disp_df(files):
    disptable_info = []
    for file in files:
        disptable = fits.open(file, ignore_missing_simple=True)[1].data
        disptable = disptable[disptable['aperture']=="PSA"]
        cols = {}
        for col in ['SEGMENT', 'CENWAVE', 'OPT_ELEM','COEFF', 'D_TV03', 'D']:
            cols[col] = disptable[col]
        cols['disptab']=file
        disptable_info.append(cols)
    disp_df = pd.DataFrame(disptable_info).set_index('disptab')
    return disp_df

def make_lsf_df(files):
    lsf_info = []
    for file in files:
        # This is the table of all the LSFs: called "lsf"
        # The first column is a list of the wavelengths corresponding to the line profile, so we set our header accordingly
        hs = 0
        lsf = Table.read(file, format="ascii", header_start=hs)

        # This is the range of each LSF in pixels (for FUV from -160 to +160, inclusive)
        # middle pixel of the lsf is considered zero ; center is relative zero
        pix = np.arange(len(lsf)) - len(lsf) // 2  # integer division to yield whole pixels

        # the column names returned as integers.
        lsf_wvlns = np.array([int(float(k)) for k in lsf.keys()])
        lsf_info.append({'lsf_file':file, 'lsf':lsf, 'pix':pix, 'w':lsf_wvlns})
    lsf_df = pd.DataFrame(lsf_info).set_index('lsf_file')
    return lsf_df

#disp_df = make_disp_df(set(list(set(line_df['dispfile']))+list(set(blue_df['dispfile']))+list(set(red_df['dispfile']))))
#lsf_df = make_lsf_df(set(list(set(line_df['LSFfile']))+list(set(blue_df['LSFfile']))+list(set(red_df['LSFfile']))))

# %%
#disp_df.to_pickle(os.path.join('data','disp_df.pkl'))
#lsf_df.to_pickle(os.path.join('data','lsf_df.pkl'))
disp_df = pd.read_pickle('data/disp_df.pkl')
lsf_df = pd.read_pickle('data/lsf_df.pkl')

# %%
initial_guess_line_df = {
    1521.59: {'amp1':{'init':1e-13, 'min':5e-14, 'max':2e-13},
                     'sig1':{'init':5e-2, 'min':0.02, 'max':0.08},
                     'cen1':{'init':1521.59, 'min':1521.59-0.5, 'max':1521.59+0.5},
                     'amp2':{'init':4e-14, 'min':None, 'max':5e-14},
                     'sig2':{'init':0.1, 'min':0.08, 'max':0.5},
                     'cen2':{'init':1521.59, 'min':1521.59-0.5, 'max':1521.59+0.5},
                     'bgl':{'init':4.8e-14, 'min':None, 'max':None}},

    1463.83: {'amp1':{'init':5e-13, 'min':2e-13, 'max':8e-12},
                     'sig1':{'init':5.5e-2, 'min':4.8e-2, 'max':7e-2},
                     'cen1':{'init':1463.83, 'min':1463.83-0.5, 'max':1463.83+0.5},
                     'amp2':{'init':1.5e-13, 'min':1e-13, 'max':2e-13},
                     'sig2':{'init':1.8e-1, 'min':1.5e-1, 'max':2e-1},
                     'cen2':{'init':1463.83, 'min':1463.83-0.5, 'max':1463.83+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1460.17: {'amp1':{'init':8.5e-13, 'min':3e-13, 'max':9e-13},
                     'sig1':{'init':3e-2, 'min':1.5e-2, 'max':5.6e-2},
                     'cen1':{'init':1460.17, 'min':1460.17-0.5, 'max':1460.17+0.5},
                     'amp2':{'init':7.5e-14, 'min':6e-14, 'max':2.9e-13},
                     'sig2':{'init':1e-1, 'min':5.6e-2, 'max':2e-1},
                     'cen2':{'init':1460.17, 'min':1460.17-0.5, 'max':1460.17+0.5},
                     'bgl':{'init':8e-13, 'min':None, 'max':None}},

    1398.95: {'amp1':{'init':4.5e-13, 'min':3e-13, 'max':7e-13},
                     'sig1':{'init':3e-2, 'min':1e-2, 'max':5.5e-2},
                     'cen1':{'init':1398.95, 'min':1398.95-0.5, 'max':1398.95+0.5},
                     'amp2':{'init':2e-13, 'min':1e-13, 'max':2.9e-13},
                     'sig2':{'init':1e-1, 'min':5.6e-2, 'max':2e-1},
                     'cen2':{'init':1398.95, 'min':1398.95-0.5, 'max':1398.95+0.5},
                     'bgl':{'init':4e-14, 'min':None, 'max':None}},

    1636.34: {'amp1':{'init':1.65e-13, 'min':6.9e-14, 'max':2.5e-13},
                     'sig1':{'init':1e-1, 'min':6e-2, 'max':1.5e-1},
                     'cen1':{'init':1636.34, 'min':1636.34-0.5, 'max':1636.34+0.5},
                     'amp2':{'init':6.5e-14, 'min':6.2e-14, 'max':6.9e-14},
                     'sig2':{'init':5e-2, 'min':3e-2, 'max':6e-2}, #this one the shorter comp. is narrower too
                     'cen2':{'init':1636.34, 'min':1636.34-0.5, 'max':1636.34+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1591.32: {'amp1':{'init':1.75e-13, 'min':9e-14, 'max':3e-13},
                     'sig1':{'init':1.5e-1, 'min':8e-2, 'max':2.5e-1},
                     'cen1':{'init':1591.32, 'min':1591.32-0.5, 'max':1591.32+0.5},
                     'amp2':{'init':6e-14, 'min':5e-14, 'max':8.9e-14},
                     'sig2':{'init':4.5e-2, 'min':1e-2, 'max':8e-2},
                     'cen2':{'init':1591.32, 'min':1591.32-0.5, 'max':1591.32+0.5},
                     'bgl':{'init':7e-14, 'min':None, 'max':None}},

    1431.01: {'amp1':{'init':1e-13, 'min':8e-14, 'max':3.8e-13},
                     'sig1':{'init':5e-2, 'min':4e-2, 'max':7e-2},
                     'cen1':{'init':1431.01, 'min':1431.01-0.5, 'max':1431.01+0.5},
                     'amp2':{'init':8.5e-14, 'min':4e-14, 'max':1.5e-13},
                     'sig2':{'init':1.3e-1, 'min':7e-2, 'max':1.9e-1},
                     'cen2':{'init':1431.01, 'min':1431.01-0.5, 'max':1431.01+0.5},
                     'bgl':{'init':3e-14, 'min':None, 'max':None}},

    1446.12: {'amp1':{'init':6.5e-13, 'min':3e-13, 'max':1e-12},
                     'sig1':{'init':6.3e-2, 'min':5.3e-2, 'max':7e-2},
                     'cen1':{'init':1446.12, 'min':1446.12-0.5, 'max':1446.12+0.5},
                     'amp2':{'init':2e-13, 'min':1e-13, 'max':3e-13},
                     'sig2':{'init':1.5e-1, 'min':7e-2, 'max':3e-1},
                     'cen2':{'init':1446.12, 'min':1446.12-0.5, 'max':1446.12+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1489.57: {'amp1':{'init':6.5e-13, 'min':4e-13, 'max':1.3e-12},
                     'sig1':{'init':6e-2, 'min':5e-2, 'max':7e-2},
                     'cen1':{'init':1489.57, 'min':1489.57-0.5, 'max':1489.57+0.5},
                     'amp2':{'init':1.5e-13, 'min':1e-13, 'max':3e-13},
                     'sig2':{'init':2.3e-1, 'min':1e-1, 'max':3.8e-1},
                     'cen2':{'init':1489.57, 'min':1489.57-0.5, 'max':1489.57+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1504.76: {'amp1':{'init':9e-13, 'min':6e-13, 'max':1.5e-12},
                     'sig1':{'init':6e-2, 'min':4e-2, 'max':8e-2},
                     'cen1':{'init':1504.76, 'min':1504.76-1, 'max':1504.76+0.2},
                     'amp2':{'init':2e-13, 'min':1e-13, 'max':5e-13},
                     'sig2':{'init':1.7e-1, 'min':1e-1, 'max':2.5e-1},
                     'cen2':{'init':1504.76, 'min':1504.76-1, 'max':1504.76+0.2},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1467.08: {'amp1':{'init':2e-13, 'min':1.5e-13, 'max':5e-13},
                     'sig1':{'init':3e-2, 'min':1e-2, 'max':7e-2},
                     'cen1':{'init':1467.08, 'min':1467.08-0.5, 'max':1467.08+0.5},
                     'amp2':{'init':6.8e-14, 'min':5e-14, 'max':1.5e-13},
                     'sig2':{'init':1.3e-1, 'min':1e-1, 'max':2.5e-1},
                     'cen2':{'init':1467.08, 'min':1467.08-0.5, 'max':1467.08+0.5},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},

    1500.45: {'amp1':{'init':4e-13, 'min':2e-13, 'max':8e-13},
                     'sig1':{'init':6e-2, 'min':4e-2, 'max':8e-2},
                     'cen1':{'init':1500.45, 'min':1500.45-1, 'max':1500.45+0.2},
                     'amp2':{'init':1.6e-13, 'min':5e-14, 'max':2e-13},
                     'sig2':{'init':1.2e-1, 'min':1e-1, 'max':5e-1},
                     'cen2':{'init':1500.45, 'min':1500.45-1, 'max':1500.45+0.2},
                     'bgl':{'init':5e-14, 'min':None, 'max':None}},
}

# %%
for line in line_df_coadded['labline'].unique():
    test_df = line_df_coadded[line_df_coadded['labline']==line].copy()
    guess_fit = ModelFitting(test_df, line_mask_dict, disp_df, lsf_df, verbose=False)
    if line in initial_guess_line_df:
        print(f'fitting for line {line}')
        guess_fit.fit_lines(double_guess = initial_guess_line_df[line])
    else:
        print(f'amp error for line {line}')
        #guess_fit.fit_lines()
        pass
    test_df.to_pickle(f'data/test_df_{line}.pkl')
# Out:
# fitting for line 1463.83
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# bootstrapping
# fitting for line 1460.17
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# fitting for line 1398.95
# fitting for line 1521.59
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# bootstrapping
# fitting for line 1431.01
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# fitting for line 1446.12
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# fitting for line 1489.57
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# fitting for line 1504.76
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# fitting for line 1467.08
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# fitting for line 1500.45
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# fitting for line 1591.32
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 6
#       4 if line in initial_guess_line_df:
#       5     print(f'fitting for line {line}')
# ----> 6     guess_fit.fit_lines(double_guess = initial_guess_line_df[line])
#       7 else:
#       8     print(f'amp error for line {line}')
#
# File /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/empirical_functions.py:1073, in ModelFitting.fit_lines(self, double_guess)
#    1071 # Fit gaussians
#    1072 params1, err_dict1, bic1, yerrGauss = self.fit_oneGauss(x, y, yerr, conv_args)
# -> 1073 params2, err_dict2, bic2, y2errGauss, xconv = self.fit_twoGauss(x, y, yerr, params1, double_guess, conv_args)
#    1075 #Construct gaussian
#    1076 ygauss = self.gaussian_conv(x=x, lsf_file=row['LSFfile'], disptab=row['dispfile'], cenwave=row['cenwave'], filt=row['filter'], segment=row['segment'], **params1)
#
# File /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/empirical_functions.py:889, in ModelFitting.fit_twoGauss(self, x, y, yerr, bestPar, double_guess, conv_args)
#     886     self.doubleLineParam['bgl'].set(min=0.6*bestPar['bgl'], max=1e-12)
#     888 lsf_file, disptab, cenwave, filt, segment = conv_args
# --> 889 doubleFit = self.doubleLineModel.fit(y,
#     890                             self.doubleLineParam,
#     891                             x=x,
#     892                             weights=1/yerr,
#     893                             scale_covar=False,
#     894                             lsf_file=lsf_file,
#     895                             disptab=disptab,
#     896                             cenwave=cenwave,
#     897                             filt=filt,
#     898                             segment=segment
#     899                             )
#     901 best2par = doubleFit.params
#     902 param_dict = {param:best2par[param].value for param in self.doubleLineModel.param_names}
#
# File /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/lmfit/model.py:1111, in Model.fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, calc_covar, max_nfev, coerce_farray, **kwargs)
#    1109     params = self.make_params(verbose=verbose)
#    1110 else:
# -> 1111     params = deepcopy(params)
#    1113 # If any kwargs match parameter names, override params.
#    1114 param_kwargs = set(kwargs.keys()) & set(self.param_names)
#
# File /usr/lib/python3.12/copy.py:143, in deepcopy(x, memo, _nil)
#     141 copier = getattr(x, "__deepcopy__", None)
#     142 if copier is not None:
# --> 143     y = copier(memo)
#     144 else:
#     145     reductor = dispatch_table.get(cls)
#
# File /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/lmfit/parameter.py:148, in Parameters.__deepcopy__(self, memo)
#     146 for key, par in self.items():
#     147     if isinstance(par, Parameter):
# --> 148         param = Parameter(name=par.name,
#     149                           value=par.value,
#     150                           min=par.min,
#     151                           max=par.max)
#     152         param.vary = par.vary
#     153         param.brute_step = par.brute_step
#
# File /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/lmfit/parameter.py:790, in Parameter.__init__(self, name, value, vary, min, max, expr, brute_step, user_data)
#     788 self.from_internal = lambda val: val
#     789 self._val = value
# --> 790 self._init_bounds()
#
# File /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/lmfit/parameter.py:883, in Parameter._init_bounds(self)
#     881     self.min, self.max = self.max, self.min
#     882 if isclose(self.min, self.max, atol=1e-13, rtol=1e-13):
# --> 883     raise ValueError(f"Parameter '{self.name}' has min == max")
#     884 if self._val > self.max:
#     885     self._val = self.max
#
# ValueError: Parameter 'amp2' has min == max

# %%
#Takes about half an hour on a desktop
fitting = ModelFitting(line_df_coadded, line_mask_dict, disp_df, lsf_df, verbose=False)
blue_fitting = ModelFitting(blue_df_coadded, line_mask_dict, disp_df, lsf_df, verbose=False)
red_fitting = ModelFitting(red_df_coadded, line_mask_dict, disp_df, lsf_df, verbose=False)
fitting.fit_lines()
blue_fitting.fit_lines()
red_fitting.fit_lines()
# Out:
# bootstrapping
# /mnt/c/Users/Prerana Kottapalli/Documents/GitHub/scripts_by_me/research24/astrotest/astro-venv/lib/python3.12/site-packages/uncertainties/core.py:1024: UserWarning: Using UFloat objects with std_dev==0 may give unexpected results.
#   warn("Using UFloat objects with std_dev==0 may give unexpected results.")
# bootstrapping

# %%
line_df_coadded.to_pickle(os.path.join('data','line_df_coadded.pkl'))
red_df_coadded.to_pickle(os.path.join('data','red_df_coadded.pkl'))
blue_df_coadded.to_pickle(os.path.join('data','blue_df_coadded.pkl'))

# %%
line_df.to_pickle(os.path.join('data','line_df_local.pkl'))
red_df.to_pickle(os.path.join('data','red_df.pkl'))
blue_df.to_pickle(os.path.join('data','blue_df.pkl'))

# %%
#make an SNR cut to remove lines whose fit errors are high. This ensures we keep good fits only.
#first, make the cut based on the single gauss fit. Cut if fit SNR < data SNR
def SNR(signal, noise):
    #normalize the signal
    normsignal = signal/np.max(signal)
    normnoise = noise/np.max(noise)
    return np.mean(normsignal/normnoise)

def snr_mask(df, low, high):
    ratio = df.apply(lambda r: SNR(r['gauss_flux'], r['gauss_fluxerr']) /
                               SNR(r['flux'], r['fluxerr']), axis=1)
    return df[ratio.between(low, high)]

red_df_cut  = snr_mask(red_df,  1.3, 13)
blue_df_cut = snr_mask(blue_df, 1.3, 16)
line_df_cut = snr_mask(line_df, 0.8, 100)

# %% [markdown]
# # Coadd lines in velocity space
# Coadding has to be done after the fits because of the convolution with the COS LSF (takes place in wavelength space).
# Coadding by progression will allow me to reproduced the lyman alpha profile for each observation date.
# If I coadd the emission line data and then fit a gaussian to them, that might give me some baseline parameter estimations.

# %%
shift_all = True
line_prog_df = all_spectra.coaddvel(line_df_cut, columns=['transition', 'obsdate'], shift_all=shift_all)
blue_prog_df = all_spectra.coaddvel(blue_df_cut, columns=['transition'], shift_all=shift_all)
red_prog_df = all_spectra.coaddvel(red_df_cut, columns=['transition'], shift_all=shift_all)
prog_df = pd.concat([line_prog_df, blue_prog_df, red_prog_df], ignore_index=True, sort=False)

# %%
line_prog_df.to_pickle(os.path.join('data','line_prog_df_local.pkl'))
red_prog_df.to_pickle(os.path.join('data','red_prog_df.pkl'))
blue_prog_df.to_pickle(os.path.join('data','blue_prog_df.pkl'))
