# %%
import numpy as np
import pandas as pd
import astropy.units as u
import astropy.constants as const

# %%
file_path = "co.dat.txt"
df_energy = pd.read_csv(file_path, delim_whitespace=True, skiprows=7, nrows=41, header=None, names=["Level", "Energy (cm^-1)", "Weight", "J"])
# # Read Radiative Transitions (Rows 145-185, assuming it starts at row 145)
df_radiative = pd.read_csv(file_path, delim_whitespace=True, skiprows=51, nrows=40, header=None,names=["Transition", "Upper Level", "Lower Level", "Einstein A (s^-1)", "Frequency (GHz)", "E_u (K)"])
# Read Collisional Transitions (Rows 187+)
df_collisional = pd.read_csv(file_path, delim_whitespace=True, skiprows=102, nrows=819,names=['Trans+','Up+','Low+','2.0','5.0','10.0','20.0','30.0','40.0','50.0','60.0','70.0','80.0','90.0','100.0','150.0','200.0','300.0','400.0','500.0','600.0','700.0','750.0','800.0','900.0','1000.0','2000.0','3000.0'], header=None)
df10K = df_collisional[['Trans+','Up+','Low+','10.0']].loc[0:45]
df10K
# Out:
# C:\Users\Prerana Kottapalli\AppData\Local\Temp\ipykernel_18048\3811392733.py:2: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_energy = pd.read_csv(file_path, delim_whitespace=True, skiprows=7, nrows=41, header=None, names=["Level", "Energy (cm^-1)", "Weight", "J"])
# C:\Users\Prerana Kottapalli\AppData\Local\Temp\ipykernel_18048\3811392733.py:4: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df_radiative = pd.read_csv(file_path, delim_whitespace=True, skiprows=51, nrows=40, header=None,names=["Transition", "Upper Level", "Lower Level", "Einstein A (s^-1)", "Frequency (GHz)", "E_u (K)"])
# ...

# %%
cdr = df10K.loc[df10K['Up+']-df10K['Low+']==1]['10.0']
df10K.loc[df10K['Up+']-df10K['Low+']==1]
# Out:
#     Trans+  Up+  Low+          10.0
# 0        1    2     1  3.302000e-11
# 2        3    3     2  7.150000e-11
# 5        6    4     3  7.946000e-11
# 9       10    5     4  8.114000e-11
# 14      15    6     5  6.553000e-11
# 20      21    7     6  5.799000e-11
# 27      28    8     7  5.807000e-11
# 35      36    9     8  6.315000e-11
# 44      45   10     9  7.198000e-11

# %%
eins = df_radiative.loc[0:8]['Einstein A (s^-1)']
df_radiative.loc[0:8]
# Out:
#    Transition  Upper Level  Lower Level  Einstein A (s^-1)  Frequency (GHz)  \
# 0           1            2            1       7.203000e-08       115.271202
# 1           2            3            2       6.910000e-07       230.538000
# 2           3            4            3       2.497000e-06       345.795990
# 3           4            5            4       6.126000e-06       461.040768
# 4           5            6            5       1.221000e-05       576.267931
# 5           6            7            6       2.137000e-05       691.473076
# 6           7            8            7       3.422000e-05       806.651806
# 7           8            9            8       5.134000e-05       921.799700
# 8           9           10            9       7.330000e-05      1036.912393
#
#    E_u (K)
# 0     5.53
# 1    16.60
# 2    33.19
# 3    55.32
# 4    82.97
# 5   116.16
# 6   154.87
# 7   199.11
# 8   248.88

# %%
eins
# Out:
# 0    7.203000e-08
# 1    6.910000e-07
# 2    2.497000e-06
# 3    6.126000e-06
# 4    1.221000e-05
# 5    2.137000e-05
# 6    3.422000e-05
# 7    5.134000e-05
# 8    7.330000e-05
# Name: Einstein A (s^-1), dtype: float64

# %%
n_crit = eins.values/cdr.values

# %%
n=100/(u.cm**3)
mach=10
sigma2 = np.log(1+(0.75*mach**2))
def mass_frac(n):
